# %% [markdown]
# # 1. Imports

# %%
import pandas as pd
from sklearn import preprocessing
import numpy as np

# %% [markdown]
# # 2. Importing the Datasets

# %%
ddos_portmap_2018_df = pd.read_csv("../data/train_test/CSE_CIC_IDS2018/ddos_portmap_2018_train.csv")

# %%
ddos_ldap_2019_df = pd.read_csv("../data/train_test/CIC_DDoS2019/ddos_ldap_2019_train.csv")

# %%
ddos_netbios_2019_df = pd.read_csv("../data/train_test/CIC_DDoS2019/ddos_netbios_2019_train.csv")

# %%
ddos_syn_2019_df = pd.read_csv("../data/train_test/CIC_DDoS2019/ddos_syn_2019_train.csv")

# %%
ddos_udp_2019_df = pd.read_csv("../data/train_test/CIC_DDoS2019/ddos_udp_2019_train.csv")

# %%
target_feature = 'Label'

# %% [markdown]
# # 3. Feature Selection Method

# %%
from sklearn.feature_selection import mutual_info_classif

def MutualInformation_Helper(X_train, y_train, threshold):
    new_X_train = X_train.copy()

    # Calculate mutual information between each feature and the target variable
    mi_scores = mutual_info_classif(new_X_train, y_train)

    # Create a boolean mask to filter features based on the threshold
    selected_features_mask = mi_scores > threshold

    # Select features based on the mask
    new_X_train = new_X_train.loc[:, selected_features_mask]

    return new_X_train.columns.tolist()

# %%
def stable_MutualInformation(train_df, num_splits, threshold, verbose):
    
    selectedFeatures = []
    
    df_split = np.array_split(train_df, num_splits)
    
    for small_df in df_split:
        X_train = small_df.drop([target_feature], axis=1)
        y_train = small_df[target_feature]
        
        selectedFeatures = selectedFeatures + MutualInformation_Helper(X_train, y_train, threshold)
       
        
    rank_data = {}
    features = train_df.columns.tolist()
    ranks = []
        
    for feature in features:
        if verbose :
            print("Feature: "+feature+". Count: "+str(selectedFeatures.count(feature))+"/"+str(num_splits))
        ranks.append(selectedFeatures.count(feature)/num_splits)
    
    rank_data = {'feature':features, 'rank':ranks}
    rank_df = pd.DataFrame(rank_data) 
    
    return rank_df

# %%
portmap_ranking = stable_MutualInformation(ddos_syn_2019_df, 10, 0.005, verbose=False)

# %%
portmap_ranking.head(20)
# Out:
#                     feature  rank
# 0                Unnamed: 0   0.5
# 1                    FlowID   1.0
# 2                  SourceIP   1.0
# 3                SourcePort   1.0
# 4             DestinationIP   1.0
# 5           DestinationPort   1.0
# 6                  Protocol   1.0
# 7              FlowDuration   1.0
# 8           TotalFwdPackets   0.5
# 9      TotalBackwardPackets   0.6
# 10  TotalLengthofFwdPackets   1.0
# 11  TotalLengthofBwdPackets   1.0
# 12       FwdPacketLengthMax   1.0
# 13       FwdPacketLengthMin   1.0
# 14      FwdPacketLengthMean   1.0
# 15       FwdPacketLengthStd   0.4
# 16       BwdPacketLengthMax   1.0
# 17       BwdPacketLengthMin   1.0
# 18      BwdPacketLengthMean   1.0
# 19       BwdPacketLengthStd   0.1

# %%
portmap_ranking = stable_MutualInformation(ddos_portmap_2018_df, 10, 0.00005, verbose=False)
portmap_ranking.to_csv("../ranking/CSE_CIC_IDS2018/ddos_portmap_2018_MutualInformation.csv")
portmap_ranking.head(20)
# Out:
#                     feature  rank
# 0                Unnamed: 0   1.0
# 1           DestinationPort   1.0
# 2              FlowDuration   1.0
# 3           TotalFwdPackets   1.0
# 4      TotalBackwardPackets   1.0
# 5   TotalLengthofFwdPackets   1.0
# 6   TotalLengthofBwdPackets   1.0
# 7        FwdPacketLengthMax   1.0
# 8        FwdPacketLengthMin   1.0
# 9       FwdPacketLengthMean   1.0
# 10       FwdPacketLengthStd   1.0
# 11       BwdPacketLengthMax   1.0
# 12       BwdPacketLengthMin   1.0
# 13      BwdPacketLengthMean   1.0
# 14       BwdPacketLengthStd   1.0
# 15              FlowBytes/s   1.0
# 16            FlowPackets/s   1.0
# 17              FlowIATMean   1.0
# 18               FlowIATStd   1.0
# 19               FlowIATMax   1.0

# %% [markdown]
# # 4. Saving the Ranking

# %% [markdown]
# CODE TO SAVE A CSV FILE WITH:
# - 'feature' is a column of all of the features in the original dataset
# - 'ranking' is a column with the rankings (in range 0 to 1) of the feature

# %%
portmap_ranking = stable_MutualInformation(ddos_portmap_2018_df, 10, 0.0005, verbose=False)
portmap_ranking.to_csv("../ranking/CSE_CIC_IDS2018/ddos_portmap_2018_MutualInformation.csv")
portmap_ranking.head(20)
# Out:
#                     feature  rank
# 0                Unnamed: 0   1.0
# 1           DestinationPort   1.0
# 2              FlowDuration   1.0
# 3           TotalFwdPackets   1.0
# 4      TotalBackwardPackets   1.0
# 5   TotalLengthofFwdPackets   1.0
# 6   TotalLengthofBwdPackets   1.0
# 7        FwdPacketLengthMax   1.0
# 8        FwdPacketLengthMin   1.0
# 9       FwdPacketLengthMean   1.0
# 10       FwdPacketLengthStd   1.0
# 11       BwdPacketLengthMax   1.0
# 12       BwdPacketLengthMin   1.0
# 13      BwdPacketLengthMean   1.0
# 14       BwdPacketLengthStd   1.0
# 15              FlowBytes/s   1.0
# 16            FlowPackets/s   1.0
# 17              FlowIATMean   1.0
# 18               FlowIATStd   1.0
# 19               FlowIATMax   1.0

# %%
ldap_ranking = stable_MutualInformation(ddos_ldap_2019_df, 10, 0.005, verbose=False)
ldap_ranking.to_csv("../ranking/CIC_DDoS2019/ddos_ldap_2019_MutualInformation.csv")
ldap_ranking.head(20)
# Out:
#                     feature  rank
# 0                Unnamed: 0   1.0
# 1                    FlowID   1.0
# 2                  SourceIP   1.0
# 3                SourcePort   1.0
# 4             DestinationIP   1.0
# 5           DestinationPort   1.0
# 6                  Protocol   1.0
# 7              FlowDuration   1.0
# 8           TotalFwdPackets   1.0
# 9      TotalBackwardPackets   1.0
# 10  TotalLengthofFwdPackets   1.0
# 11  TotalLengthofBwdPackets   1.0
# 12       FwdPacketLengthMax   1.0
# 13       FwdPacketLengthMin   1.0
# 14      FwdPacketLengthMean   1.0
# 15       FwdPacketLengthStd   1.0
# 16       BwdPacketLengthMax   1.0
# 17       BwdPacketLengthMin   1.0
# 18      BwdPacketLengthMean   1.0
# 19       BwdPacketLengthStd   1.0

# %%
netbios_ranking = stable_MutualInformation(ddos_netbios_2019_df, 10, 0.0005, verbose=False)
netbios_ranking.to_csv("../ranking/CIC_DDoS2019/ddos_netbios_2019_MutualInformation.csv")
netbios_ranking.head(20)
# Out:
#                     feature  rank
# 0                Unnamed: 0   1.0
# 1                    FlowID   1.0
# 2                  SourceIP   1.0
# 3                SourcePort   1.0
# 4             DestinationIP   1.0
# 5           DestinationPort   1.0
# 6                  Protocol   1.0
# 7              FlowDuration   1.0
# 8           TotalFwdPackets   1.0
# 9      TotalBackwardPackets   1.0
# 10  TotalLengthofFwdPackets   1.0
# 11  TotalLengthofBwdPackets   1.0
# 12       FwdPacketLengthMax   1.0
# 13       FwdPacketLengthMin   1.0
# 14      FwdPacketLengthMean   1.0
# 15       FwdPacketLengthStd   1.0
# 16       BwdPacketLengthMax   1.0
# 17       BwdPacketLengthMin   1.0
# 18      BwdPacketLengthMean   1.0
# 19       BwdPacketLengthStd   1.0

# %%
syn_ranking = stable_MutualInformation(ddos_syn_2019_df, 10, 0.005, verbose=False)
syn_ranking.to_csv("../ranking/CIC_DDoS2019/ddos_syn_2019_MutualInformation.csv")
syn_ranking.head(20)
# Out:
#                     feature  rank
# 0                Unnamed: 0   0.5
# 1                    FlowID   1.0
# 2                  SourceIP   1.0
# 3                SourcePort   1.0
# 4             DestinationIP   1.0
# 5           DestinationPort   1.0
# 6                  Protocol   1.0
# 7              FlowDuration   1.0
# 8           TotalFwdPackets   0.5
# 9      TotalBackwardPackets   0.6
# 10  TotalLengthofFwdPackets   1.0
# 11  TotalLengthofBwdPackets   1.0
# 12       FwdPacketLengthMax   1.0
# 13       FwdPacketLengthMin   1.0
# 14      FwdPacketLengthMean   1.0
# 15       FwdPacketLengthStd   0.4
# 16       BwdPacketLengthMax   1.0
# 17       BwdPacketLengthMin   1.0
# 18      BwdPacketLengthMean   1.0
# 19       BwdPacketLengthStd   0.2

# %%
udp_ranking = stable_MutualInformation(ddos_udp_2019_df, 10, 0.05, verbose=False)
udp_ranking.to_csv("../ranking/CIC_DDoS2019/ddos_udp_2019_MutualInformation.csv")
udp_ranking.head(20)
# Out:
#                     feature  rank
# 0                Unnamed: 0   1.0
# 1                    FlowID   1.0
# 2                  SourceIP   1.0
# 3                SourcePort   1.0
# 4             DestinationIP   1.0
# 5           DestinationPort   1.0
# 6                  Protocol   1.0
# 7              FlowDuration   1.0
# 8           TotalFwdPackets   1.0
# 9      TotalBackwardPackets   1.0
# 10  TotalLengthofFwdPackets   1.0
# 11  TotalLengthofBwdPackets   1.0
# 12       FwdPacketLengthMax   1.0
# 13       FwdPacketLengthMin   1.0
# 14      FwdPacketLengthMean   1.0
# 15       FwdPacketLengthStd   1.0
# 16       BwdPacketLengthMax   1.0
# 17       BwdPacketLengthMin   1.0
# 18      BwdPacketLengthMean   1.0
# 19       BwdPacketLengthStd   0.9
