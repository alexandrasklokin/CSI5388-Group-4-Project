# %% [markdown]
# # 1. Imports

# %%
import pandas as pd
import numpy as np

# TESTING
from sklearn.metrics import classification_report, precision_score, recall_score, f1_score, precision_recall_curve, auc
import matplotlib.pyplot as plt
from sklearn.metrics import make_scorer
from numpy import mean
from numpy import std
import statistics
import scipy.stats as stats

# TRAINING
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

# SAVING
import pickle

# MODELS
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import LinearSVC
from xgboost import XGBClassifier

# %%
import warnings
from sklearn.exceptions import ConvergenceWarning

# Ignore ConvergenceWarning
warnings.simplefilter('ignore', ConvergenceWarning)

# %% [markdown]
# # 2. Importing the Ranking Files

# %%
portmap_ranking = pd.read_csv("../final_ranking/CSE_CIC_IDS2018/ddos_portmap_2018.csv", index_col=0)
syn_ranking = pd.read_csv("../final_ranking/CIC_DDoS2019/ddos_syn_2019.csv", index_col=0)
udp_ranking = pd.read_csv("../final_ranking/CIC_DDoS2019/ddos_udp_2019.csv", index_col=0)
netbios_ranking = pd.read_csv("../final_ranking/CIC_DDoS2019/ddos_netbios_2019.csv", index_col=0)
ldap_ranking = pd.read_csv("../final_ranking/CIC_DDoS2019/ddos_ldap_2019.csv", index_col=0)

# %% [markdown]
# # 3. Importing the Training Datasets

# %%
portmap_train = pd.read_csv("../data/train_test/CSE_CIC_IDS2018/ddos_portmap_2018_train.csv", index_col=0)
ldap_train = pd.read_csv("../data/train_test/CIC_DDoS2019/ddos_ldap_2019_train.csv", index_col=0)
netbios_train = pd.read_csv("../data/train_test/CIC_DDoS2019/ddos_netbios_2019_train.csv", index_col=0)
syn_train = pd.read_csv("../data/train_test/CIC_DDoS2019/ddos_syn_2019_train.csv", index_col=0)
udp_train = pd.read_csv("../data/train_test/CIC_DDoS2019/ddos_udp_2019_train.csv", index_col=0)

# %%
portmap_test = pd.read_csv("../data/train_test/CSE_CIC_IDS2018/ddos_portmap_2018_test.csv", index_col=0)
ldap_test = pd.read_csv("../data/train_test/CIC_DDoS2019/ddos_ldap_2019_test.csv", index_col=0)
netbios_test = pd.read_csv("../data/train_test/CIC_DDoS2019/ddos_netbios_2019_test.csv", index_col=0)
syn_test = pd.read_csv("../data/train_test/CIC_DDoS2019/ddos_syn_2019_test.csv", index_col=0)
udp_test = pd.read_csv("../data/train_test/CIC_DDoS2019/ddos_udp_2019_test.csv", index_col=0)

# %%
target_feature = 'Label'

# %% [markdown]
# # 3. Training the Model

# %%
def trainTestModel(train_df, test_df, master_ranking, baseModel, cv_n, verbose):
    
    if verbose: print("Model: "+str(baseModel))
    
    cv = KFold(n_splits=cv_n, random_state=1, shuffle=True)
    f1_scorer = make_scorer(f1_score, average='weighted')
    
    methods = master_ranking.columns.tolist()[1:-1]
    methods.insert(0, 'AllFeatures')
    methods.append("STEF-Rank_0.1")
    methods.append("STEF-Rank_0.2")
    methods.append("STEF-Rank_0.25")
    methods.append("STEF-Rank_0.3")
    methods.append("STEF-Rank_0.4")
    methods.append("STEF-Rank_0.5")
    methods.append("STEF-Rank_0.6")
    methods.append("STEF-Rank_0.7")
    methods.append("STEF-Rank_0.75")
    methods.append("STEF-Rank_0.8")
    methods.append("STEF-Rank_0.9")
    #if verbose: print(methods)
    
    features = master_ranking['feature'].tolist()
    #if verbose: print(features)
    
    aggregated_data = []
        
    for method in methods:
        print("Training using "+method+"...")
        if verbose: print("_________________________________________________________________________________")
            
        # _____________________________________________________________1. CREATE X BASED ON THE FEATURE SELECTED DURING FEATURE SELECTION
        
        # BASELINES
        if method == 'AllFeatures':
            selected_features = master_ranking['feature'].tolist()
        elif not ("STEF-Rank" in method):
            selected_features = master_ranking[master_ranking[method] == 1]['feature'].tolist()
        # STEF-RANK
        else:
            threshold = method.split("_")[1]
            #print(threshold)
            selected_features = master_ranking[master_ranking['STEF-Rank'] >= float(threshold)]['feature'].tolist()
            
        #if verbose: print(selected_features)
            
        X_train = train_df[selected_features]
        X_test = test_df[selected_features]
        
        y_train = train_df[target_feature].values
        y_test = test_df[target_feature].values
                
        if verbose: print("Training Dataset size: rows =", X_train.shape[0], ", columns =", X_train.shape[1], "+ 'Label'")
            
        if X_train.shape[1] == 0:
            
            temp = {'method':method,'mean_cv_f1':'nan','test_f1':'nan','auc_pr':'nan'}
            
        else:

            # _____________________________________________________________2. TRAIN THE MODEL USING CV (K=5)
            model = baseModel()
            model.fit(X_train, y_train)
            f1s = cross_val_score(model, X_train, y_train, scoring=f1_scorer, cv=cv, n_jobs=-1)

            if verbose: print('CV F1-Score Mean (std): %.3f (%.3f)' % (mean(f1s), std(f1s)))

            if verbose: print("Testing Dataset size: rows =", X_test.shape[0], ", columns =", X_test.shape[1], "+ 'Label'")

            if verbose: print("~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~")
            # _____________________________________________________________3. EVALUATE THE MODEL
            y_preds = model.predict(X_test)
            test_f1 = f1_score(y_test, y_preds)

            y_pred_prob = model.predict_proba(X_test)
            y_pred_prob = y_pred_prob[:, 1]
            precision, recall, _ = precision_recall_curve(y_test, y_pred_prob)
            auc_pr = auc(recall, precision)

            if verbose: print("Test F1-Scrore "+str(test_f1))
            if verbose: print("Test AUC-PR "+str(auc_pr))

            # _____________________________________________________________4. SAVE THE MODEL RESULTS

            temp = {'method':method,'num_features':len(selected_features),'mean_cv_f1':mean(f1s),'test_f1':test_f1,'auc_pr':auc_pr}
        
        aggregated_data.append(temp)
        
        results_df = pd.DataFrame(aggregated_data)
        
    return results_df

# %%
portmap_performance = trainTestModel(portmap_train, portmap_test, portmap_ranking, LogisticRegression, 10, verbose=False)
portmap_performance
# Out:
# Training using AllFeatures...
# Training using BackwardElimination...
# Training using MutualInformation...
# Training using RFE...
# Training using SelectKBest...
# Training using VarianceThreshold...
# Training using VIF...
# Training using STEF-Rank_0.1...
# Training using STEF-Rank_0.2...
# Training using STEF-Rank_0.25...
# Training using STEF-Rank_0.3...
# Training using STEF-Rank_0.4...
# Training using STEF-Rank_0.5...
# Training using STEF-Rank_0.6...
# Training using STEF-Rank_0.7...
# Training using STEF-Rank_0.75...
# Training using STEF-Rank_0.8...
# Training using STEF-Rank_0.9...
#                  method  num_features  mean_cv_f1   test_f1    auc_pr
# 0           AllFeatures            78    0.988995  0.989853  0.999704
# 1   BackwardElimination            50    0.986332  0.987441  0.999619
# 2     MutualInformation            65    0.988518  0.989561  0.999720
# 3                   RFE            50    0.985760  0.987008  0.999460
# 4           SelectKBest            40    0.985544  0.987199  0.999573
# 5     VarianceThreshold            36    0.988239  0.989293  0.999690
# 6                   VIF            13    0.965879  0.970487  0.971184
# 7         STEF-Rank_0.1            73    0.988995  0.989853  0.999704
# 8         STEF-Rank_0.2            69    0.988995  0.989853  0.999704
# 9        STEF-Rank_0.25            68    0.988995  0.989853  0.999704
# 10        STEF-Rank_0.3            68    0.988995  0.989853  0.999704
# 11        STEF-Rank_0.4            66    0.989008  0.989866  0.999715
# 12        STEF-Rank_0.5            57    0.988982  0.989840  0.999711
# 13        STEF-Rank_0.6            46    0.988925  0.989751  0.999690
# 14        STEF-Rank_0.7            34    0.984927  0.986382  0.998861
# 15       STEF-Rank_0.75            25    0.984310  0.985823  0.998773
# 16        STEF-Rank_0.8            14    0.958341  0.964571  0.987817
# 17        STEF-Rank_0.9             2    0.893199  0.915033  0.594613

# %%
udp_performance = trainTestModel(udp_train, udp_test, udp_ranking, LogisticRegression, 10, verbose=False)
udp_performance
# Out:
# Training using AllFeatures...
# Training using BackwardElimination...
# Training using MutualInformation...
# Training using RFE...
# Training using SelectKBest...
# Training using VarianceThreshold...
# Training using VIF...
# Training using STEF-Rank_0.1...
# Training using STEF-Rank_0.2...
# Training using STEF-Rank_0.25...
# Training using STEF-Rank_0.3...
# Training using STEF-Rank_0.4...
# Training using STEF-Rank_0.5...
# Training using STEF-Rank_0.6...
# Training using STEF-Rank_0.7...
# Training using STEF-Rank_0.75...
# Training using STEF-Rank_0.8...
# Training using STEF-Rank_0.9...
#                  method  num_features mean_cv_f1   test_f1    auc_pr
# 0           AllFeatures          85.0   0.998391  0.996143    0.9999
# 1   BackwardElimination          50.0   0.998391  0.996143   0.99994
# 2     MutualInformation          59.0   0.998391  0.996143  0.999935
# 3                   RFE          50.0   0.998391  0.993953  0.999948
# 4           SelectKBest          40.0   0.998621  0.996143  0.999869
# 5     VarianceThreshold          37.0   0.998391  0.996143  0.999871
# 6                   VIF          20.0   0.997932  0.993953  0.999964
# 7         STEF-Rank_0.1          73.0   0.998391  0.996143    0.9999
# 8         STEF-Rank_0.2          73.0   0.998391  0.996143    0.9999
# 9        STEF-Rank_0.25          72.0   0.998391  0.996143    0.9999
# 10        STEF-Rank_0.3          71.0   0.998391  0.996143    0.9999
# 11        STEF-Rank_0.4          70.0   0.998391  0.996143    0.9999
# 12        STEF-Rank_0.5          63.0   0.998391  0.995595  0.999901
# 13        STEF-Rank_0.6          45.0   0.998391  0.996143  0.999956
# 14        STEF-Rank_0.7          29.0   0.997472  0.996143  0.997996
# 15       STEF-Rank_0.75          23.0   0.997242  0.996143  0.998888
# 16        STEF-Rank_0.8           4.0   0.974457  0.969437  0.957183
# 17        STEF-Rank_0.9           NaN        nan       nan       nan

# %%
netbios_performance = trainTestModel(netbios_train, netbios_test, netbios_ranking, LogisticRegression, 10, verbose=False)
netbios_performance
# Out:
# Training using AllFeatures...
# Training using BackwardElimination...
# Training using MutualInformation...
# Training using RFE...
# Training using SelectKBest...
# Training using VarianceThreshold...
# Training using VIF...
# Training using STEF-Rank_0.1...
# Training using STEF-Rank_0.2...
# Training using STEF-Rank_0.25...
# Training using STEF-Rank_0.3...
# Training using STEF-Rank_0.4...
# Training using STEF-Rank_0.5...
# Training using STEF-Rank_0.6...
# Training using STEF-Rank_0.7...
# Training using STEF-Rank_0.75...
# Training using STEF-Rank_0.8...
# Training using STEF-Rank_0.9...
#                  method  num_features mean_cv_f1   test_f1    auc_pr
# 0           AllFeatures          85.0   0.999872  0.999967         1
# 1   BackwardElimination          50.0   0.999823  0.999958         1
# 2     MutualInformation          57.0   0.999865  0.999967         1
# 3                   RFE          50.0   0.999625  0.999875         1
# 4           SelectKBest          40.0   0.999695  0.999908  0.999999
# 5     VarianceThreshold           7.0   0.998253  0.999275  0.999967
# 6                   VIF          15.0   0.999462  0.999817  0.999965
# 7         STEF-Rank_0.1          74.0   0.999872  0.999967         1
# 8         STEF-Rank_0.2          72.0   0.999872  0.999967         1
# 9        STEF-Rank_0.25          72.0   0.999872  0.999967         1
# 10        STEF-Rank_0.3          71.0   0.999872  0.999967         1
# 11        STEF-Rank_0.4          67.0   0.999872  0.999967         1
# 12        STEF-Rank_0.5          54.0   0.999865  0.999958         1
# 13        STEF-Rank_0.6          38.0   0.999844  0.999967         1
# 14        STEF-Rank_0.7          15.0   0.994598  0.997655  0.998887
# 15       STEF-Rank_0.75           9.0   0.990049  0.996238   0.99997
# 16        STEF-Rank_0.8           3.0   0.988178  0.995817  0.999459
# 17        STEF-Rank_0.9           NaN        nan       nan       nan

# %%
syn_performance = trainTestModel(syn_train, syn_test, syn_ranking, LogisticRegression, 10, verbose=False)
syn_performance
# Out:
# Training using AllFeatures...
# Training using BackwardElimination...
# Training using MutualInformation...
# Training using RFE...
# Training using SelectKBest...
# Training using VarianceThreshold...
# Training using VIF...
# Training using STEF-Rank_0.1...
# Training using STEF-Rank_0.2...
# Training using STEF-Rank_0.25...
# Training using STEF-Rank_0.3...
# Training using STEF-Rank_0.4...
# Training using STEF-Rank_0.5...
# Training using STEF-Rank_0.6...
# Training using STEF-Rank_0.7...
# Training using STEF-Rank_0.75...
# Training using STEF-Rank_0.8...
# Training using STEF-Rank_0.9...
#                  method  num_features mean_cv_f1   test_f1    auc_pr
# 0           AllFeatures          85.0   0.999814  0.999867         1
# 1   BackwardElimination          50.0   0.999712  0.999783  0.999996
# 2     MutualInformation          45.0   0.999741   0.99985  0.999999
# 3                   RFE          50.0   0.999757  0.999783         1
# 4           SelectKBest          40.0    0.99967  0.999733         1
# 5     VarianceThreshold          10.0   0.994814  0.998403  0.999626
# 6                   VIF          17.0   0.999638   0.99975         1
# 7         STEF-Rank_0.1          82.0   0.999814  0.999867         1
# 8         STEF-Rank_0.2          74.0   0.999814  0.999867         1
# 9        STEF-Rank_0.25          71.0   0.999814  0.999867         1
# 10        STEF-Rank_0.3          64.0   0.999814  0.999867         1
# 11        STEF-Rank_0.4          52.0   0.999814  0.999867         1
# 12        STEF-Rank_0.5          39.0   0.999829   0.99985         1
# 13        STEF-Rank_0.6          27.0   0.999728  0.999783         1
# 14        STEF-Rank_0.7          13.0   0.999597    0.9998  0.999991
# 15       STEF-Rank_0.75           6.0   0.999246  0.999567  0.999932
# 16        STEF-Rank_0.8           NaN        nan       nan       nan
# 17        STEF-Rank_0.9           NaN        nan       nan       nan

# %%
ldap_performance = trainTestModel(ldap_train, ldap_test, ldap_ranking, LogisticRegression, 10, verbose=False)
ldap_performance
# Out:
# Training using AllFeatures...
# Training using BackwardElimination...
# Training using MutualInformation...
# Training using RFE...
# Training using SelectKBest...
# Training using VarianceThreshold...
# Training using VIF...
# Training using STEF-Rank_0.1...
# Training using STEF-Rank_0.2...
# Training using STEF-Rank_0.25...
# Training using STEF-Rank_0.3...
# Training using STEF-Rank_0.4...
# Training using STEF-Rank_0.5...
# Training using STEF-Rank_0.6...
# Training using STEF-Rank_0.7...
# Training using STEF-Rank_0.75...
# Training using STEF-Rank_0.8...
# Training using STEF-Rank_0.9...
#                  method  num_features  mean_cv_f1   test_f1    auc_pr
# 0           AllFeatures            85    0.999944  0.999917  1.000000
# 1   BackwardElimination            50    0.999923  0.999908  1.000000
# 2     MutualInformation            47    0.999937  0.999917  1.000000
# 3                   RFE            50    0.999805  0.999833  1.000000
# 4           SelectKBest            40    0.999833  0.999933  0.999999
# 5     VarianceThreshold            17    0.999889  0.999917  1.000000
# 6                   VIF            18    0.999228  0.999750  1.000000
# 7         STEF-Rank_0.1            75    0.999944  0.999917  1.000000
# 8         STEF-Rank_0.2            73    0.999944  0.999917  1.000000
# 9        STEF-Rank_0.25            73    0.999944  0.999917  1.000000
# 10        STEF-Rank_0.3            73    0.999944  0.999917  1.000000
# 11        STEF-Rank_0.4            70    0.999944  0.999917  1.000000
# 12        STEF-Rank_0.5            53    0.999937  0.999917  1.000000
# 13        STEF-Rank_0.6            44    0.999840  0.999908  0.999999
# 14        STEF-Rank_0.7            30    0.999708  0.999783  1.000000
# 15       STEF-Rank_0.75            22    0.999631  0.999767  0.999999
# 16        STEF-Rank_0.8             4    0.998264  0.999167  0.500091
# 17        STEF-Rank_0.9             1    0.998062  0.999059  0.499883

# %%
# Combine all performance metrics into one dataframe

portmap_performance['dataset'] = 'portmap_2018'
netbios_performance['dataset'] = 'netbios_2019'
syn_performance['dataset'] = 'syn_2019'
ldap_performance['dataset'] = 'ldap_2019'
udp_performance['dataset'] = 'udp_2019'

master_df = pd.concat([portmap_performance, netbios_performance, syn_performance, ldap_performance, udp_performance])

# If you want the new column to be the first column
column_order = ['dataset'] + [col for col in udp_performance.columns if not (col in ['dataset'])]
master_df = master_df[column_order]

# %%
master_df.to_csv('../performance/performance.csv')

# %%
master_df
# Out:
#          dataset               method  num_features mean_cv_f1   test_f1  \
# 0   portmap_2018          AllFeatures          78.0   0.988995  0.989853
# 1   portmap_2018  BackwardElimination          50.0   0.986332  0.987441
# 2   portmap_2018    MutualInformation          65.0   0.988518  0.989561
# 3   portmap_2018                  RFE          50.0    0.98576  0.987008
# 4   portmap_2018          SelectKBest          40.0   0.985544  0.987199
# ..           ...                  ...           ...        ...       ...
# 13      udp_2019        STEF-Rank_0.6          45.0   0.998391  0.996143
# 14      udp_2019        STEF-Rank_0.7          29.0   0.997472  0.996143
# 15      udp_2019       STEF-Rank_0.75          23.0   0.997242  0.996143
# 16      udp_2019        STEF-Rank_0.8           4.0   0.974457  0.969437
# 17      udp_2019        STEF-Rank_0.9           NaN        nan       nan
#
#       auc_pr
# 0   0.999704
# 1   0.999619
# 2    0.99972
# 3    0.99946
# 4   0.999573
# ..       ...
# 13  0.999956
# 14  0.997996
# 15  0.998888
# 16  0.957183
# 17       nan
#
# [90 rows x 6 columns]

# %% [markdown]
# # 4. Tests for Statistical Significance

# %%
def myTTest(new_method, old_method, new_scores, old_scores,measure):

    t_stat, p_value = stats.ttest_rel(old_scores, new_scores)

    print(f'T-statistic: {t_stat}')
    print(f'P-value: {p_value}')

    # Check if the results are significant
    # Typically, if p < 0.05, we reject the null hypothesis
    alpha = 0.05
    if p_value < alpha:
        print('The difference in the mean '+measure+' is statistically significant; '+new_method+' outperforms '+old_method+'.')
    else:
        print('The difference in the mean '+measure+' cannot be proved to be statistically significant; '+new_method+
              ' may not outperform '+old_method+'.')

# %%
def myWilcoxon(new_method, old_method, new_scores, old_scores, measure):
    
    stat, p_value = stats.wilcoxon(old_scores, new_scores)

    print(f'Wilcoxon Statistic: {stat}')
    print(f'P-value: {p_value}')

    # Check if the results are significant
    # Typically, if p < 0.05, we reject the null hypothesis
    alpha = 0.05
    if p_value < alpha:
        print('The difference in the median '+measure+' is statistically significant; '+new_method+' outperforms '+old_method+'.')
    else:
        print('The difference in the median '+measure+' cannot be proved to be statistically significant; '+new_method+
              ' may not outperform '+old_method+'.')

# %%
baseline_methods = ['AllFeatures','BackwardElimination','MutualInformation','RFE','SelectKBest','VarianceThreshold','VIF']
new_methods = ['STEF-Rank_0.1','STEF-Rank_0.2','STEF-Rank_0.25','STEF-Rank_0.3','STEF-Rank_0.4',
               'STEF-Rank_0.5','STEF-Rank_0.6','STEF-Rank_0.7','STEF-Rank_0.75','STEF-Rank_0.8',
              'STEF-Rank_0.9']

# %%
for bm in baseline_methods:
    for nm in new_methods:
        print("____________________________________________________________________________________________")
        
        base_f1s = master_df[master_df['method'] == bm]['test_f1'].tolist()
        new_f1s = master_df[master_df['method'] == nm]['test_f1'].tolist()
        
        base_aucs = master_df[master_df['method'] == bm]['auc_pr'].tolist()
        new_aucs = master_df[master_df['method'] == nm]['auc_pr'].tolist()
        
        base_f1s, new_f1s = zip(*[(x, y) for x, y in zip(base_f1s, new_f1s) if isinstance(x, float) and isinstance(y, float)])
        
        base_aucs, new_aucs = zip(*[(x, y) for x, y in zip(base_aucs, new_aucs) if isinstance(x, float) and isinstance(y, float)])
        
        myTTest(nm,bm,new_f1s,base_f1s,'F1')
        #myWilcoxon(nm,bm,new_f1s,base_f1s,'F1')
        
        myTTest(nm,bm,new_aucs,base_aucs,'AUC-PR')
        #myWilcoxon(nm,bm,new_aucs,base_aucs,'AUC-PR')
# Out:
# ____________________________________________________________________________________________
# T-statistic: nan
# P-value: nan
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.1 may not outperform AllFeatures.
# T-statistic: -1.0
# P-value: 0.373900966300059
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.1 may not outperform AllFeatures.
# ____________________________________________________________________________________________
# T-statistic: nan
# P-value: nan
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.2 may not outperform AllFeatures.
# T-statistic: 1.0000000000000002
# P-value: 0.3739009663000589
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.2 may not outperform AllFeatures.
# ____________________________________________________________________________________________
# T-statistic: nan
# P-value: nan
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.25 may not outperform AllFeatures.
# T-statistic: 0.9553303901299178
# P-value: 0.39350950893163195
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.25 may not outperform AllFeatures.
# ____________________________________________________________________________________________
# T-statistic: nan
# P-value: nan
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.3 may not outperform AllFeatures.
# T-statistic: 0.9254965396325998
# P-value: 0.4070895757732657
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.3 may not outperform AllFeatures.
# ____________________________________________________________________________________________
# T-statistic: -1.0
# P-value: 0.373900966300059
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.4 may not outperform AllFeatures.
# T-statistic: -1.0065146601749202
# P-value: 0.371113161965072
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.4 may not outperform AllFeatures.
# ____________________________________________________________________________________________
# T-statistic: 1.0872946575116404
# P-value: 0.3380382998452324
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.5 may not outperform AllFeatures.
# T-statistic: -1.2214043334444455
# P-value: 0.288996348657354
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.5 may not outperform AllFeatures.
# ____________________________________________________________________________________________
# T-statistic: 1.7384786581085812
# P-value: 0.15711718443556713
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.6 may not outperform AllFeatures.
# T-statistic: -0.6778774622921414
# P-value: 0.5350358836851664
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.6 may not outperform AllFeatures.
# ____________________________________________________________________________________________
# T-statistic: 1.6709598334623605
# P-value: 0.17004946788017922
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.7 may not outperform AllFeatures.
# T-statistic: 2.1533544953576023
# P-value: 0.09761360338979494
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.7 may not outperform AllFeatures.
# ____________________________________________________________________________________________
# T-statistic: 1.7923554105161092
# P-value: 0.14754540607308214
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.75 may not outperform AllFeatures.
# T-statistic: 1.7697738223465085
# P-value: 0.15147954385391618
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.75 may not outperform AllFeatures.
# ____________________________________________________________________________________________
# T-statistic: 2.0797802202312656
# P-value: 0.129029662802522
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.8 may not outperform AllFeatures.
# T-statistic: 1.1495502728470144
# P-value: 0.33366097840009695
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.8 may not outperform AllFeatures.
# ____________________________________________________________________________________________
# T-statistic: 1.0232021356507375
# P-value: 0.4926995476275874
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.9 may not outperform AllFeatures.
# T-statistic: 9.525912494806136
# P-value: 0.0665864367203683
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.9 may not outperform AllFeatures.
# ____________________________________________________________________________________________
# T-statistic: -1.0518042792655584
# P-value: 0.35223198920042353
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.1 may not outperform BackwardElimination.
# T-statistic: -0.47932316499877814
# P-value: 0.6567370505995881
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.1 may not outperform BackwardElimination.
# ____________________________________________________________________________________________
# T-statistic: -1.0518042792655584
# P-value: 0.35223198920042353
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.2 may not outperform BackwardElimination.
# T-statistic: -0.4792225943185403
# P-value: 0.6568026512395416
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.2 may not outperform BackwardElimination.
# ____________________________________________________________________________________________
# T-statistic: -1.0518042792655584
# P-value: 0.35223198920042353
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.25 may not outperform BackwardElimination.
# T-statistic: -0.47875938063637985
# P-value: 0.6571048463315581
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.25 may not outperform BackwardElimination.
# ____________________________________________________________________________________________
# T-statistic: -1.0518042792655584
# P-value: 0.35223198920042353
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.3 may not outperform BackwardElimination.
# T-statistic: -0.47878187580587245
# P-value: 0.6570901689197095
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.3 may not outperform BackwardElimination.
# ____________________________________________________________________________________________
# T-statistic: -1.051530716670227
# P-value: 0.35234343532451823
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.4 may not outperform BackwardElimination.
# T-statistic: -0.5336766788377236
# P-value: 0.6218422909514902
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.4 may not outperform BackwardElimination.
# ____________________________________________________________________________________________
# T-statistic: -0.746773900729583
# P-value: 0.49670307429925276
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.5 may not outperform BackwardElimination.
# T-statistic: -0.5284701571925843
# P-value: 0.6251355968453081
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.5 may not outperform BackwardElimination.
# ____________________________________________________________________________________________
# T-statistic: -1.0044958804886768
# P-value: 0.3719751085247232
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.6 may not outperform BackwardElimination.
# T-statistic: -1.3196369497395917
# P-value: 0.25741721472895335
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.6 may not outperform BackwardElimination.
# ____________________________________________________________________________________________
# T-statistic: 1.5456350903962746
# P-value: 0.19708708838370717
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.7 may not outperform BackwardElimination.
# T-statistic: 2.089005846350254
# P-value: 0.10494857732696254
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.7 may not outperform BackwardElimination.
# ____________________________________________________________________________________________
# T-statistic: 1.608439113944072
# P-value: 0.18302098290403138
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.75 may not outperform BackwardElimination.
# T-statistic: 1.752196534794338
# P-value: 0.15461905403384468
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.75 may not outperform BackwardElimination.
# ____________________________________________________________________________________________
# T-statistic: 2.0832865476341373
# P-value: 0.12859823580439436
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.8 may not outperform BackwardElimination.
# T-statistic: 1.1494099310431038
# P-value: 0.33371070048316626
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.8 may not outperform BackwardElimination.
# ____________________________________________________________________________________________
# T-statistic: 1.0237486575658403
# P-value: 0.49252962023277375
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.9 may not outperform BackwardElimination.
# T-statistic: 9.516467677194388
# P-value: 0.06665204019325731
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.9 may not outperform BackwardElimination.
# ____________________________________________________________________________________________
# T-statistic: -1.070627986835446
# P-value: 0.3446386078648809
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.1 may not outperform MutualInformation.
# T-statistic: 1.4290805482637292
# P-value: 0.22618864168402553
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.1 may not outperform MutualInformation.
# ____________________________________________________________________________________________
# T-statistic: -1.070627986835446
# P-value: 0.3446386078648809
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.2 may not outperform MutualInformation.
# T-statistic: 1.4294599226149
# P-value: 0.22608720822161804
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.2 may not outperform MutualInformation.
# ____________________________________________________________________________________________
# T-statistic: -1.070627986835446
# P-value: 0.3446386078648809
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.25 may not outperform MutualInformation.
# T-statistic: 1.4311756882640707
# P-value: 0.2256290313006406
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.25 may not outperform MutualInformation.
# ____________________________________________________________________________________________
# T-statistic: -1.070627986835446
# P-value: 0.3446386078648809
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.3 may not outperform MutualInformation.
# T-statistic: 1.4310757651447534
# P-value: 0.22565568920924892
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.3 may not outperform MutualInformation.
# ____________________________________________________________________________________________
# T-statistic: -1.0676922686395884
# P-value: 0.34581313365065747
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.4 may not outperform MutualInformation.
# T-statistic: 1.1263752662279807
# P-value: 0.32300838910825913
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.4 may not outperform MutualInformation.
# ____________________________________________________________________________________________
# T-statistic: 0.4117043294363291
# P-value: 0.7016614351261035
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.5 may not outperform MutualInformation.
# T-statistic: 1.2656553557916597
# P-value: 0.27433602565635556
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.5 may not outperform MutualInformation.
# ____________________________________________________________________________________________
# T-statistic: -0.5271947250815893
# P-value: 0.6259439712509225
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.6 may not outperform MutualInformation.
# T-statistic: 0.2092508864101849
# P-value: 0.8444771722417922
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.6 may not outperform MutualInformation.
# ____________________________________________________________________________________________
# T-statistic: 1.6887547864528636
# P-value: 0.16653589149353207
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.7 may not outperform MutualInformation.
# T-statistic: 2.146743904504423
# P-value: 0.098340283269095
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.7 may not outperform MutualInformation.
# ____________________________________________________________________________________________
# T-statistic: 1.794987793496275
# P-value: 0.14709393497695467
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.75 may not outperform MutualInformation.
# T-statistic: 1.7638818571521078
# P-value: 0.1525243027888489
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.75 may not outperform MutualInformation.
# ____________________________________________________________________________________________
# T-statistic: 2.0809980103296217
# P-value: 0.12887962823925495
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.8 may not outperform MutualInformation.
# T-statistic: 1.149688900718704
# P-value: 0.33361187083972166
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.8 may not outperform MutualInformation.
# ____________________________________________________________________________________________
# T-statistic: 1.023294142556472
# P-value: 0.4926709338690476
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.9 may not outperform MutualInformation.
# T-statistic: 9.52762871566298
# P-value: 0.06657452970443326
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.9 may not outperform MutualInformation.
# ____________________________________________________________________________________________
# T-statistic: -1.7512927373305895
# P-value: 0.15478233946656736
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.1 may not outperform RFE.
# T-statistic: -0.754791640372287
# P-value: 0.49237817199352574
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.1 may not outperform RFE.
# ____________________________________________________________________________________________
# T-statistic: -1.7512927373305895
# P-value: 0.15478233946656736
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.2 may not outperform RFE.
# T-statistic: -0.7547734283251261
# P-value: 0.4923879635464133
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.2 may not outperform RFE.
# ____________________________________________________________________________________________
# T-statistic: -1.7512927373305895
# P-value: 0.15478233946656736
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.25 may not outperform RFE.
# T-statistic: -0.7546981232850763
# P-value: 0.49242845222674936
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.25 may not outperform RFE.
# ____________________________________________________________________________________________
# T-statistic: -1.7512927373305895
# P-value: 0.15478233946656736
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.3 may not outperform RFE.
# T-statistic: -0.754707864519536
# P-value: 0.49242321459052635
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.3 may not outperform RFE.
# ____________________________________________________________________________________________
# T-statistic: -1.750044689548855
# P-value: 0.1550081200148091
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.4 may not outperform RFE.
# T-statistic: -0.7653660440497475
# P-value: 0.48671781473274717
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.4 may not outperform RFE.
# ____________________________________________________________________________________________
# T-statistic: -1.6769755103095703
# P-value: 0.1688530626596023
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.5 may not outperform RFE.
# T-statistic: -0.7673060053481215
# P-value: 0.4856847718991879
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.5 may not outperform RFE.
# ____________________________________________________________________________________________
# T-statistic: -1.7079312720816957
# P-value: 0.16283480491749233
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.6 may not outperform RFE.
# T-statistic: -1.038318592985757
# P-value: 0.3577633529279959
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.6 may not outperform RFE.
# ____________________________________________________________________________________________
# T-statistic: 0.19452825130539442
# P-value: 0.8552426869876322
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.7 may not outperform RFE.
# T-statistic: 1.994179224911438
# P-value: 0.11689107092738783
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.7 may not outperform RFE.
# ____________________________________________________________________________________________
# T-statistic: 0.6181773669515481
# P-value: 0.5699194600844053
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.75 may not outperform RFE.
# T-statistic: 1.718658904105022
# P-value: 0.1608022495116033
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.75 may not outperform RFE.
# ____________________________________________________________________________________________
# T-statistic: 2.1010510323803473
# P-value: 0.12643863773318356
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.8 may not outperform RFE.
# T-statistic: 1.1489693198898274
# P-value: 0.3338668540720433
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.8 may not outperform RFE.
# ____________________________________________________________________________________________
# T-statistic: 1.0217599940920092
# P-value: 0.4931483916691143
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.9 may not outperform RFE.
# T-statistic: 9.498908047615869
# P-value: 0.066774351902307
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.9 may not outperform RFE.
# ____________________________________________________________________________________________
# T-statistic: -1.0824015315402278
# P-value: 0.3399641585152394
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.1 may not outperform SelectKBest.
# T-statistic: -1.2971820635754263
# P-value: 0.2643287200052204
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.1 may not outperform SelectKBest.
# ____________________________________________________________________________________________
# T-statistic: -1.0824015315402278
# P-value: 0.3399641585152394
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.2 may not outperform SelectKBest.
# T-statistic: -1.2972199786805176
# P-value: 0.264316899641047
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.2 may not outperform SelectKBest.
# ____________________________________________________________________________________________
# T-statistic: -1.0824015315402278
# P-value: 0.3399641585152394
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.25 may not outperform SelectKBest.
# T-statistic: -1.2974449321311403
# P-value: 0.2642467789638261
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.25 may not outperform SelectKBest.
# ____________________________________________________________________________________________
# T-statistic: -1.0824015315402278
# P-value: 0.3399641585152394
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.3 may not outperform SelectKBest.
# T-statistic: -1.2974699641911818
# P-value: 0.26423897728490586
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.3 may not outperform SelectKBest.
# ____________________________________________________________________________________________
# T-statistic: -1.0820062524441698
# P-value: 0.34012016550152163
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.4 may not outperform SelectKBest.
# T-statistic: -1.2768329105189575
# P-value: 0.2707469681041725
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.4 may not outperform SelectKBest.
# ____________________________________________________________________________________________
# T-statistic: -0.7999729090385566
# P-value: 0.4685411554901179
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.5 may not outperform SelectKBest.
# T-statistic: -1.2936344406269669
# P-value: 0.26543698765950124
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.5 may not outperform SelectKBest.
# ____________________________________________________________________________________________
# T-statistic: -1.040656728913696
# P-value: 0.3567988412023744
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.6 may not outperform SelectKBest.
# T-statistic: -1.6159091252044488
# P-value: 0.18141839750549327
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.6 may not outperform SelectKBest.
# ____________________________________________________________________________________________
# T-statistic: 1.4503567063027798
# P-value: 0.22056984639488414
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.7 may not outperform SelectKBest.
# T-statistic: 2.0931818095763095
# P-value: 0.10445448508878956
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.7 may not outperform SelectKBest.
# ____________________________________________________________________________________________
# T-statistic: 1.5504638488787201
# P-value: 0.1959671386729216
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.75 may not outperform SelectKBest.
# T-statistic: 1.7671384982640217
# P-value: 0.15194589382905418
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.75 may not outperform SelectKBest.
# ____________________________________________________________________________________________
# T-statistic: 2.0814811997704825
# P-value: 0.12882015564851435
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.8 may not outperform SelectKBest.
# T-statistic: 1.1490831098008383
# P-value: 0.33382651965906623
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.8 may not outperform SelectKBest.
# ____________________________________________________________________________________________
# T-statistic: 1.0245392072807287
# P-value: 0.49228398268728474
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.9 may not outperform SelectKBest.
# T-statistic: 9.511506719273026
# P-value: 0.06668655050570839
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.9 may not outperform SelectKBest.
# ____________________________________________________________________________________________
# T-statistic: -2.0104264940440575
# P-value: 0.11474312191900583
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.1 may not outperform VarianceThreshold.
# T-statistic: -1.2634871695385572
# P-value: 0.2750374882145648
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.1 may not outperform VarianceThreshold.
# ____________________________________________________________________________________________
# T-statistic: -2.0104264940440575
# P-value: 0.11474312191900583
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.2 may not outperform VarianceThreshold.
# T-statistic: -1.2634178184156926
# P-value: 0.27505995339453565
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.2 may not outperform VarianceThreshold.
# ____________________________________________________________________________________________
# T-statistic: -2.0104264940440575
# P-value: 0.11474312191900583
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.25 may not outperform VarianceThreshold.
# T-statistic: -1.2630729843670334
# P-value: 0.27517168294980776
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.25 may not outperform VarianceThreshold.
# ____________________________________________________________________________________________
# T-statistic: -2.0104264940440575
# P-value: 0.11474312191900583
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.3 may not outperform VarianceThreshold.
# T-statistic: -1.2630713654561472
# P-value: 0.2751722075951058
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.3 may not outperform VarianceThreshold.
# ____________________________________________________________________________________________
# T-statistic: -2.0195103550788662
# P-value: 0.11356107887657976
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.4 may not outperform VarianceThreshold.
# T-statistic: -1.3042488806517305
# P-value: 0.2621343983713243
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.4 may not outperform VarianceThreshold.
# ____________________________________________________________________________________________
# T-statistic: -1.2683265824646552
# P-value: 0.2734741760054535
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.5 may not outperform VarianceThreshold.
# T-statistic: -1.2929063246062513
# P-value: 0.2656650041908787
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.5 may not outperform VarianceThreshold.
# ____________________________________________________________________________________________
# T-statistic: -1.961697069705474
# P-value: 0.12131835344236233
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.6 may not outperform VarianceThreshold.
# T-statistic: -1.3895929592367622
# P-value: 0.2369984878468033
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.6 may not outperform VarianceThreshold.
# ____________________________________________________________________________________________
# T-statistic: 0.8839827977433986
# P-value: 0.4266382560258471
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.7 may not outperform VarianceThreshold.
# T-statistic: 1.7189105052909326
# P-value: 0.1607549013928143
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.7 may not outperform VarianceThreshold.
# ____________________________________________________________________________________________
# T-statistic: 1.205796428793607
# P-value: 0.2943423655352809
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.75 may not outperform VarianceThreshold.
# T-statistic: 1.2054598776412488
# P-value: 0.294458661921192
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.75 may not outperform VarianceThreshold.
# ____________________________________________________________________________________________
# T-statistic: 2.030534242487947
# P-value: 0.13527430799070275
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.8 may not outperform VarianceThreshold.
# T-statistic: 1.1493336859304293
# P-value: 0.33373771668620433
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.8 may not outperform VarianceThreshold.
# ____________________________________________________________________________________________
# T-statistic: 1.0233793387782901
# P-value: 0.4926444405512326
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.9 may not outperform VarianceThreshold.
# T-statistic: 9.524346880886354
# P-value: 0.06659730253827928
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.9 may not outperform VarianceThreshold.
# ____________________________________________________________________________________________
# T-statistic: -1.1687517858415013
# P-value: 0.3074052386146885
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.1 may not outperform VIF.
# T-statistic: -0.9987341064875748
# P-value: 0.37444479014946125
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.1 may not outperform VIF.
# ____________________________________________________________________________________________
# T-statistic: -1.1687517858415013
# P-value: 0.3074052386146885
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.2 may not outperform VIF.
# T-statistic: -0.9987341056659356
# P-value: 0.374444790502658
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.2 may not outperform VIF.
# ____________________________________________________________________________________________
# T-statistic: -1.1687517858415013
# P-value: 0.3074052386146885
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.25 may not outperform VIF.
# T-statistic: -0.9987342480067484
# P-value: 0.37444472931480677
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.25 may not outperform VIF.
# ____________________________________________________________________________________________
# T-statistic: -1.1687517858415013
# P-value: 0.3074052386146885
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.3 may not outperform VIF.
# T-statistic: -0.9987343453806822
# P-value: 0.37444468745681136
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.3 may not outperform VIF.
# ____________________________________________________________________________________________
# T-statistic: -1.1686413816247008
# P-value: 0.3074449669381492
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.4 may not outperform VIF.
# T-statistic: -0.9987370910500044
# P-value: 0.37444350718149577
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.4 may not outperform VIF.
# ____________________________________________________________________________________________
# T-statistic: -1.1326317913326414
# P-value: 0.32065968357274116
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.5 may not outperform VIF.
# T-statistic: -0.9987886166418557
# P-value: 0.37442135858015924
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.5 may not outperform VIF.
# ____________________________________________________________________________________________
# T-statistic: -1.1631137080754659
# P-value: 0.30944018259440165
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.6 may not outperform VIF.
# T-statistic: -1.0011447062073204
# P-value: 0.3734097964889942
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.6 may not outperform VIF.
# ____________________________________________________________________________________________
# T-statistic: -0.9858984319568319
# P-value: 0.37999788833889525
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.7 may not outperform VIF.
# T-statistic: -0.8639833412489887
# P-value: 0.4363285284831517
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.7 may not outperform VIF.
# ____________________________________________________________________________________________
# T-statistic: -0.8409448946918324
# P-value: 0.44771190871029154
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.75 may not outperform VIF.
# T-statistic: -0.9483098635665236
# P-value: 0.39667011844824723
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.75 may not outperform VIF.
# ____________________________________________________________________________________________
# T-statistic: 1.6305376431247465
# P-value: 0.2014828606006295
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.8 may not outperform VIF.
# T-statistic: 1.0668729630347076
# P-value: 0.36426425401418855
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.8 may not outperform VIF.
# ____________________________________________________________________________________________
# T-statistic: 1.0252492462655294
# P-value: 0.4920635266474248
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.9 may not outperform VIF.
# T-statistic: 7.0960545020016665
# P-value: 0.08912769641570284
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.9 may not outperform VIF.

# %% [markdown]
# # 5. Producing Some Graphs

# %%
# for different values of the threshold

performance_df = pd.read_csv('../performance/performance.csv', index_col=0)

# %%
performance_df
# Out:
#          dataset               method  num_features  mean_cv_f1   test_f1  \
# 0   portmap_2018          AllFeatures          78.0    0.988995  0.989853
# 1   portmap_2018  BackwardElimination          50.0    0.986332  0.987441
# 2   portmap_2018    MutualInformation          65.0    0.988518  0.989561
# 3   portmap_2018                  RFE          50.0    0.985760  0.987008
# 4   portmap_2018          SelectKBest          40.0    0.985544  0.987199
# ..           ...                  ...           ...         ...       ...
# 13      udp_2019        STEF-Rank_0.6          45.0    0.998391  0.996143
# 14      udp_2019        STEF-Rank_0.7          29.0    0.997472  0.996143
# 15      udp_2019       STEF-Rank_0.75          23.0    0.997242  0.996143
# 16      udp_2019        STEF-Rank_0.8           4.0    0.974457  0.969437
# 17      udp_2019        STEF-Rank_0.9           NaN         NaN       NaN
#
#       auc_pr
# 0   0.999704
# 1   0.999619
# 2   0.999720
# 3   0.999460
# 4   0.999573
# ..       ...
# 13  0.999956
# 14  0.997996
# 15  0.998888
# 16  0.957183
# 17       NaN
#
# [90 rows x 6 columns]

# %%
# GRAPH for Different STEF-Rank Thresholds

baseline_methods = ['AllFeatures','BackwardElimination','MutualInformation','RFE','SelectKBest','VarianceThreshold','VIF']
new_methods = ['STEF-Rank_0.1','STEF-Rank_0.2','STEF-Rank_0.25','STEF-Rank_0.3','STEF-Rank_0.4',
               'STEF-Rank_0.5','STEF-Rank_0.6','STEF-Rank_0.7','STEF-Rank_0.75','STEF-Rank_0.8',
              'STEF-Rank_0.9']
thresholds = [method.split("_")[1] for method in new_methods]

portmapF1s = performance_df[performance_df['dataset'] == 'portmap_2018']['test_f1'].tolist()[7:]
netbiosF1s = performance_df[performance_df['dataset'] == 'netbios_2019']['test_f1'].tolist()[7:]
udpF1s = performance_df[performance_df['dataset'] == 'udp_2019']['test_f1'].tolist()[7:]
synF1s = performance_df[performance_df['dataset'] == 'syn_2019']['test_f1'].tolist()[7:]
ldapF1s = performance_df[performance_df['dataset'] == 'ldap_2019']['test_f1'].tolist()[7:]


temp = statistics.mean(performance_df[performance_df['method'] == 'AllFeatures']['test_f1'].tolist())
averageAllFeatures = [temp for elem in thresholds]

temp = statistics.mean(performance_df[performance_df['method'] == 'BackwardElimination']['test_f1'].tolist())
BackwardEliminationFeatures = [temp for elem in thresholds]

temp = statistics.mean(performance_df[performance_df['method'] == 'MutualInformation']['test_f1'].tolist())
MutualInformationFeatures = [temp for elem in thresholds]

temp = statistics.mean(performance_df[performance_df['method'] == 'RFE']['test_f1'].tolist())
RFEFeatures = [temp for elem in thresholds]

temp = statistics.mean(performance_df[performance_df['method'] == 'SelectKBest']['test_f1'].tolist())
SelectKBestFeatures = [temp for elem in thresholds]

temp = statistics.mean(performance_df[performance_df['method'] == 'VarianceThreshold']['test_f1'].tolist())
VarianceThresholdFeatures = [temp for elem in thresholds]

temp = statistics.mean(performance_df[performance_df['method'] == 'VIF']['test_f1'].tolist())
VIFFeatures = [temp for elem in thresholds]
    
plt.figure(figsize=(6,6))

plt.plot([], [], marker=' ', color='white', label="STEF-Rank:")
plt.plot(thresholds, portmapF1s, marker='.', label='PORTMAP')
plt.plot(thresholds, netbiosF1s, marker='.', label='NETBIOS')
plt.plot(thresholds, udpF1s, marker='.', label='UDP')
plt.plot(thresholds, synF1s, marker='.', label='SYN')
plt.plot(thresholds, ldapF1s, marker='.', label='LDAP')
plt.plot([], [], marker=' ', color='white', label="Average of Baseline Methods:")
plt.plot(thresholds, averageAllFeatures, label='AllFeatures', linestyle="--")
plt.plot(thresholds, BackwardEliminationFeatures, label='BackwardElimination', linestyle="--")
plt.plot(thresholds, MutualInformationFeatures, label='MutualInformation', linestyle="--")
plt.plot(thresholds, RFEFeatures, label='RFE', linestyle="--")
plt.plot(thresholds, SelectKBestFeatures, label='SelectKBest', linestyle="--")
plt.plot(thresholds, VarianceThresholdFeatures, label='VarianceThreshold', linestyle="--")
plt.plot(thresholds, VIFFeatures, label='VIF', linestyle="--")


#max and min
plt.ylim(0.913,1.005)
# axis labels
plt.xlabel('Threshold Value')
plt.ylabel('F1-Score')

# show the legend
plt.legend()
# show the plot
plt.savefig("../performance/thresholdvsF1.png")

# %% [markdown]
# # 6. Repeating with Assignment Datasets

# %%
a2_ranking = pd.read_csv("../final_ranking/csi5388_assignment2_3_data/assignment2.csv", index_col=0)
a3_ranking = pd.read_csv("../final_ranking/csi5388_assignment2_3_data/assignment3.csv", index_col=0)

# %%
a2_train = pd.read_csv("../data/csi5388_assignment2_3_data/assignment2_train.csv", index_col=0)
a3_train = pd.read_csv("../data/csi5388_assignment2_3_data/assignment3_train.csv", index_col=0)

# %%
a2_test = pd.read_csv("../data/csi5388_assignment2_3_data/assignment2_test.csv", index_col=0)
a3_test = pd.read_csv("../data/csi5388_assignment2_3_data/assignment3_test.csv", index_col=0)

# %%
a2_performance = trainTestModel(a2_train, a2_test, a2_ranking, LogisticRegression, 10, verbose=False)
a2_performance
# Out:
# Training using AllFeatures...
# Training using BackwardElimination...
# Training using MutualInformation...
# Training using RFE...
# Training using SelectKBest...
# Training using VarianceThreshold...
# Training using VIF...
# Training using STEF-Rank_0.1...
# Training using STEF-Rank_0.2...
# Training using STEF-Rank_0.25...
# Training using STEF-Rank_0.3...
# Training using STEF-Rank_0.4...
# Training using STEF-Rank_0.5...
# Training using STEF-Rank_0.6...
# Training using STEF-Rank_0.7...
# Training using STEF-Rank_0.75...
# Training using STEF-Rank_0.8...
# Training using STEF-Rank_0.9...
#                  method  num_features  mean_cv_f1   test_f1    auc_pr
# 0           AllFeatures            42    0.877179  0.716812  0.913272
# 1   BackwardElimination            25    0.910466  0.770307  0.944220
# 2     MutualInformation            30    0.876881  0.721832  0.910720
# 3                   RFE            25    0.968008  0.919566  0.988833
# 4           SelectKBest            25    0.874840  0.716875  0.913150
# 5     VarianceThreshold            34    0.876923  0.716729  0.913287
# 6                   VIF            30    0.875670  0.716887  0.913201
# 7         STEF-Rank_0.1            41    0.876877  0.716909  0.913341
# 8         STEF-Rank_0.2            38    0.876837  0.716909  0.913340
# 9        STEF-Rank_0.25            38    0.876837  0.716909  0.913340
# 10        STEF-Rank_0.3            37    0.876957  0.716729  0.913295
# 11        STEF-Rank_0.4            37    0.876957  0.716729  0.913295
# 12        STEF-Rank_0.5            34    0.876923  0.716729  0.913287
# 13        STEF-Rank_0.6            30    0.876191  0.716659  0.913247
# 14        STEF-Rank_0.7            27    0.873370  0.717207  0.913292
# 15       STEF-Rank_0.75            20    0.943072  0.826499  0.966213
# 16        STEF-Rank_0.8            13    0.944839  0.897492  0.985444
# 17        STEF-Rank_0.9             6    0.943458  0.868859  0.974725

# %%
a3_performance = trainTestModel(a3_train, a3_test, a3_ranking, LogisticRegression, 10, verbose=False)
a3_performance
# Out:
# Training using AllFeatures...
# Training using BackwardElimination...
# Training using MutualInformation...
# Training using RFE...
# Training using SelectKBest...
# Training using VarianceThreshold...
# Training using VIF...
# Training using STEF-Rank_0.1...
# Training using STEF-Rank_0.2...
# Training using STEF-Rank_0.25...
# Training using STEF-Rank_0.3...
# Training using STEF-Rank_0.4...
# Training using STEF-Rank_0.5...
# Training using STEF-Rank_0.6...
# Training using STEF-Rank_0.7...
# Training using STEF-Rank_0.75...
# Training using STEF-Rank_0.8...
# Training using STEF-Rank_0.9...
#                  method  num_features mean_cv_f1   test_f1    auc_pr
# 0           AllFeatures          10.0   0.810947  0.856911  0.757627
# 1   BackwardElimination           4.0    0.81103  0.856928  0.757384
# 2     MutualInformation           6.0   0.807629  0.853246  0.759718
# 3                   RFE           4.0   0.796583  0.840589  0.751052
# 4           SelectKBest           4.0    0.81103  0.856928  0.760522
# 5     VarianceThreshold           7.0   0.811024  0.856911  0.757949
# 6                   VIF          10.0   0.810947  0.856911  0.757627
# 7         STEF-Rank_0.1          10.0   0.810947  0.856911  0.757627
# 8         STEF-Rank_0.2          10.0   0.810947  0.856911  0.757627
# 9        STEF-Rank_0.25          10.0   0.810947  0.856911  0.757627
# 10        STEF-Rank_0.3          10.0   0.810947  0.856911  0.757627
# 11        STEF-Rank_0.4           7.0   0.811024  0.856911  0.757949
# 12        STEF-Rank_0.5           7.0   0.811024  0.856911  0.757949
# 13        STEF-Rank_0.6           6.0    0.81103  0.856928  0.760005
# 14        STEF-Rank_0.7           3.0   0.810909  0.856801  0.761137
# 15       STEF-Rank_0.75           2.0   0.810909  0.856801  0.760923
# 16        STEF-Rank_0.8           2.0   0.810909  0.856801  0.760923
# 17        STEF-Rank_0.9           NaN        nan       nan       nan

# %%
# Combine all performance metrics into one dataframe

a2_performance['dataset'] = 'csi5388_assignment2'
a3_performance['dataset'] = 'csi5388_assignment3'

master_df = pd.concat([a2_performance, a3_performance])

# If you want the new column to be the first column
column_order = ['dataset'] + [col for col in a2_performance.columns if not (col in ['dataset'])]
master_df = master_df[column_order]

# %%
master_df.to_csv('../performance/performance_assignment2_3.csv')

# %%
baseline_methods = ['AllFeatures','BackwardElimination','MutualInformation','RFE','SelectKBest','VarianceThreshold','VIF']
new_methods = ['STEF-Rank_0.1','STEF-Rank_0.2','STEF-Rank_0.25','STEF-Rank_0.3','STEF-Rank_0.4',
               'STEF-Rank_0.5','STEF-Rank_0.6','STEF-Rank_0.7','STEF-Rank_0.75','STEF-Rank_0.8',
              'STEF-Rank_0.9']

# %%
for bm in baseline_methods:
    for nm in new_methods:
        print("____________________________________________________________________________________________")
        
        base_f1s = master_df[master_df['method'] == bm]['test_f1'].tolist()
        new_f1s = master_df[master_df['method'] == nm]['test_f1'].tolist()
        
        base_aucs = master_df[master_df['method'] == bm]['auc_pr'].tolist()
        new_aucs = master_df[master_df['method'] == nm]['auc_pr'].tolist()
        
        base_f1s, new_f1s = zip(*[(x, y) for x, y in zip(base_f1s, new_f1s) if isinstance(x, float) and isinstance(y, float)])
        
        base_aucs, new_aucs = zip(*[(x, y) for x, y in zip(base_aucs, new_aucs) if isinstance(x, float) and isinstance(y, float)])
        
        myTTest(nm,bm,new_f1s,base_f1s,'F1')
        #myWilcoxon(nm,bm,new_f1s,base_f1s,'F1')
        
        myTTest(nm,bm,new_aucs,base_aucs,'AUC-PR')
        #myWilcoxon(nm,bm,new_aucs,base_aucs,'AUC-PR')
# Out:
# ____________________________________________________________________________________________
# T-statistic: -1.0
# P-value: 0.49999999999999956
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.1 may not outperform AllFeatures.
# T-statistic: -1.0
# P-value: 0.49999999999999956
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.1 may not outperform AllFeatures.
# ____________________________________________________________________________________________
# T-statistic: -1.0
# P-value: 0.49999999999999956
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.2 may not outperform AllFeatures.
# T-statistic: -1.0
# P-value: 0.49999999999999956
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.2 may not outperform AllFeatures.
# ____________________________________________________________________________________________
# T-statistic: -1.0
# P-value: 0.49999999999999956
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.25 may not outperform AllFeatures.
# T-statistic: -1.0
# P-value: 0.49999999999999956
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.25 may not outperform AllFeatures.
# ____________________________________________________________________________________________
# T-statistic: 1.0
# P-value: 0.49999999999999956
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.3 may not outperform AllFeatures.
# T-statistic: -1.0
# P-value: 0.49999999999999956
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.3 may not outperform AllFeatures.
# ____________________________________________________________________________________________
# T-statistic: 1.0
# P-value: 0.49999999999999956
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.4 may not outperform AllFeatures.
# T-statistic: -1.1578224344256818
# P-value: 0.45352059717000626
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.4 may not outperform AllFeatures.
# ____________________________________________________________________________________________
# T-statistic: 1.0
# P-value: 0.49999999999999956
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.5 may not outperform AllFeatures.
# T-statistic: -1.1009912537001239
# P-value: 0.4694222526977982
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.5 may not outperform AllFeatures.
# ____________________________________________________________________________________________
# T-statistic: 0.8002988912147064
# P-value: 0.5703305674447606
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.6 may not outperform AllFeatures.
# T-statistic: -0.9791722676891575
# P-value: 0.5066991928854067
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.6 may not outperform AllFeatures.
# ____________________________________________________________________________________________
# T-statistic: -0.5643247139266934
# P-value: 0.6729209869095285
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.7 may not outperform AllFeatures.
# T-statistic: -1.0117585968790768
# P-value: 0.4962790416126702
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.7 may not outperform AllFeatures.
# ____________________________________________________________________________________________
# T-statistic: -0.9979954901640518
# P-value: 0.5006386952190858
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.75 may not outperform AllFeatures.
# T-statistic: -1.132804394320439
# P-value: 0.46041039266924977
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.75 may not outperform AllFeatures.
# ____________________________________________________________________________________________
# T-statistic: -0.9987826215357873
# P-value: 0.5003877395653695
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.8 may not outperform AllFeatures.
# T-statistic: -1.0957240069494145
# P-value: 0.47094203767805437
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.8 may not outperform AllFeatures.
# ____________________________________________________________________________________________
# T-statistic: nan
# P-value: nan
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.9 may not outperform AllFeatures.
# T-statistic: nan
# P-value: nan
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.9 may not outperform AllFeatures.
# ____________________________________________________________________________________________
# T-statistic: 1.0006344100131015
# P-value: 0.49979812506344456
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.1 may not outperform BackwardElimination.
# T-statistic: 0.9844300118171162
# P-value: 0.5049948644601632
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.1 may not outperform BackwardElimination.
# ____________________________________________________________________________________________
# T-statistic: 1.0006344100131015
# P-value: 0.49979812506344456
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.2 may not outperform BackwardElimination.
# T-statistic: 0.984430518516424
# P-value: 0.5049947006420152
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.2 may not outperform BackwardElimination.
# ____________________________________________________________________________________________
# T-statistic: 1.0006344100131015
# P-value: 0.49979812506344456
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.25 may not outperform BackwardElimination.
# T-statistic: 0.984430518516424
# P-value: 0.5049947006420152
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.25 may not outperform BackwardElimination.
# ____________________________________________________________________________________________
# T-statistic: 1.0006322752123096
# P-value: 0.49979880416140376
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.3 may not outperform BackwardElimination.
# T-statistic: 0.9844528933901416
# P-value: 0.5049874668282168
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.3 may not outperform BackwardElimination.
# ____________________________________________________________________________________________
# T-statistic: 1.0006322752123096
# P-value: 0.49979880416140376
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.4 may not outperform BackwardElimination.
# T-statistic: 0.9641178033305691
# P-value: 0.5116290250090504
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.4 may not outperform BackwardElimination.
# ____________________________________________________________________________________________
# T-statistic: 1.0006322752123096
# P-value: 0.49979880416140376
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.5 may not outperform BackwardElimination.
# T-statistic: 0.9641270194797044
# P-value: 0.5116259842806816
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.5 may not outperform BackwardElimination.
# ____________________________________________________________________________________________
# T-statistic: 1.0
# P-value: 0.49999999999999956
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.6 may not outperform BackwardElimination.
# T-statistic: 0.8439867886497171
# P-value: 0.5537341806473465
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.6 may not outperform BackwardElimination.
# ____________________________________________________________________________________________
# T-statistic: 1.0047940828954782
# P-value: 0.4984776480685989
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.7 may not outperform BackwardElimination.
# T-statistic: 0.7835744524448948
# P-value: 0.576873972434276
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.7 may not outperform BackwardElimination.
# ____________________________________________________________________________________________
# T-statistic: -0.9954908274566365
# P-value: 0.5014385551026742
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.75 may not outperform BackwardElimination.
# T-statistic: -1.3835133473195766
# P-value: 0.3984367704112665
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.75 may not outperform BackwardElimination.
# ____________________________________________________________________________________________
# T-statistic: -0.9980052602273417
# P-value: 0.5006355790864857
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.8 may not outperform BackwardElimination.
# T-statistic: -1.1878072997454134
# P-value: 0.44548448139575136
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.8 may not outperform BackwardElimination.
# ____________________________________________________________________________________________
# T-statistic: nan
# P-value: nan
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.9 may not outperform BackwardElimination.
# T-statistic: nan
# P-value: nan
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.9 may not outperform BackwardElimination.
# ____________________________________________________________________________________________
# T-statistic: 0.14645837450002105
# P-value: 0.9074199079339089
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.1 may not outperform MutualInformation.
# T-statistic: -0.11236118922790277
# P-value: 0.928767414018534
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.1 may not outperform MutualInformation.
# ____________________________________________________________________________________________
# T-statistic: 0.14645837450002105
# P-value: 0.9074199079339089
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.2 may not outperform MutualInformation.
# T-statistic: -0.1121703660290462
# P-value: 0.9288873837880405
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.2 may not outperform MutualInformation.
# ____________________________________________________________________________________________
# T-statistic: 0.14645837450002105
# P-value: 0.9074199079339089
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.25 may not outperform MutualInformation.
# T-statistic: -0.1121703660290462
# P-value: 0.9288873837880405
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.25 may not outperform MutualInformation.
# ____________________________________________________________________________________________
# T-statistic: 0.1640035518206202
# P-value: 0.8965133657396728
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.3 may not outperform MutualInformation.
# T-statistic: -0.10364874715033381
# P-value: 0.9342499397664547
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.3 may not outperform MutualInformation.
# ____________________________________________________________________________________________
# T-statistic: 0.1640035518206202
# P-value: 0.8965133657396728
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.4 may not outperform MutualInformation.
# T-statistic: -0.1856338983910334
# P-value: 0.8831518671772545
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.4 may not outperform MutualInformation.
# ____________________________________________________________________________________________
# T-statistic: 0.1640035518206202
# P-value: 0.8965133657396728
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.5 may not outperform MutualInformation.
# T-statistic: -0.18411436467565243
# P-value: 0.8840872618926778
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.5 may not outperform MutualInformation.
# ____________________________________________________________________________________________
# T-statistic: 0.16837204126632757
# c:\users\alexa\appdata\local\programs\python\python38\lib\site-packages\scipy\stats\_axis_nan_policy.py:502: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# c:\users\alexa\appdata\local\programs\python\python38\lib\site-packages\scipy\stats\_stats_py.py:1214: RuntimeWarning: divide by zero encountered in divide
#   var *= np.divide(n, n-ddof)  # to avoid error on division by zero
# c:\users\alexa\appdata\local\programs\python\python38\lib\site-packages\scipy\stats\_stats_py.py:1214: RuntimeWarning: invalid value encountered in scalar multiply
#   var *= np.divide(n, n-ddof)  # to avoid error on division by zero
# P-value: 0.8938070469744741
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.6 may not outperform MutualInformation.
# T-statistic: -1.2561792915721919
# P-value: 0.42802287695331537
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.6 may not outperform MutualInformation.
# ____________________________________________________________________________________________
# T-statistic: 0.1308189547052106
# P-value: 0.9171883319729355
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.7 may not outperform MutualInformation.
# T-statistic: -3.462253795455394
# P-value: 0.1790029087179899
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.7 may not outperform MutualInformation.
# ____________________________________________________________________________________________
# T-statistic: -1.0703169880459633
# P-value: 0.4783859265445542
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.75 may not outperform MutualInformation.
# T-statistic: -1.044398796826072
# P-value: 0.4861765182187119
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.75 may not outperform MutualInformation.
# ____________________________________________________________________________________________
# T-statistic: -1.0413114689885061
# P-value: 0.4871180323103547
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.8 may not outperform MutualInformation.
# T-statistic: -1.032785051372463
# P-value: 0.4897333943287728
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.8 may not outperform MutualInformation.
# ____________________________________________________________________________________________
# T-statistic: nan
# P-value: nan
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.9 may not outperform MutualInformation.
# T-statistic: nan
# P-value: nan
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.9 may not outperform MutualInformation.
# ____________________________________________________________________________________________
# T-statistic: 0.8509210985144946
# P-value: 0.551164874553095
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.1 may not outperform RFE.
# T-statistic: 0.8397689099158799
# P-value: 0.5553056062341892
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.1 may not outperform RFE.
# ____________________________________________________________________________________________
# T-statistic: 0.8509210985144946
# P-value: 0.551164874553095
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.2 may not outperform RFE.
# T-statistic: 0.8397708873458243
# P-value: 0.5553048679858621
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.2 may not outperform RFE.
# ____________________________________________________________________________________________
# T-statistic: 0.8509210985144946
# P-value: 0.551164874553095
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.25 may not outperform RFE.
# T-statistic: 0.8397708873458243
# P-value: 0.5553048679858621
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.25 may not outperform RFE.
# ____________________________________________________________________________________________
# T-statistic: 0.8510436979845544
# P-value: 0.5511196068593147
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.3 may not outperform RFE.
# T-statistic: 0.839858286610352
# P-value: 0.5552722400178784
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.3 may not outperform RFE.
# ____________________________________________________________________________________________
# T-statistic: 0.8510436979845544
# P-value: 0.5511196068593147
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.4 may not outperform RFE.
# T-statistic: 0.8326565116065806
# P-value: 0.557970250121584
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.4 may not outperform RFE.
# ____________________________________________________________________________________________
# T-statistic: 0.8510436979845544
# P-value: 0.5511196068593147
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.5 may not outperform RFE.
# T-statistic: 0.8326729325498944
# P-value: 0.5579640765500623
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.5 may not outperform RFE.
# ____________________________________________________________________________________________
# T-statistic: 0.8509481946466347
# P-value: 0.5511548693122148
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.6 may not outperform RFE.
# T-statistic: 0.7881920693027452
# P-value: 0.5750566843656838
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.6 may not outperform RFE.
# ____________________________________________________________________________________________
# T-statistic: 0.8516499449734494
# P-value: 0.5508958413521358
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.7 may not outperform RFE.
# T-statistic: 0.7644320743655962
# P-value: 0.5844949322179804
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.7 may not outperform RFE.
# ____________________________________________________________________________________________
# T-statistic: 0.7032821378303677
# P-value: 0.6097996053814786
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.75 may not outperform RFE.
# T-statistic: 0.3923696242247776
# P-value: 0.7619607310085671
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.75 may not outperform RFE.
# ____________________________________________________________________________________________
# T-statistic: 0.15309281369715286
# P-value: 0.9032889746891104
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.8 may not outperform RFE.
# T-statistic: -0.48883687062039893
# P-value: 0.710543446946638
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.8 may not outperform RFE.
# ____________________________________________________________________________________________
# T-statistic: nan
# P-value: nan
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.9 may not outperform RFE.
# T-statistic: nan
# P-value: nan
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.9 may not outperform RFE.
# ____________________________________________________________________________________________
# T-statistic: -0.34694147915538226
# P-value: 0.7874024281025154
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.1 may not outperform SelectKBest.
# T-statistic: 0.8763073223775169
# P-value: 0.5419075419338344
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.1 may not outperform SelectKBest.
# ____________________________________________________________________________________________
# T-statistic: -0.34694147915538226
# P-value: 0.7874024281025154
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.2 may not outperform SelectKBest.
# T-statistic: 0.8769233411639253
# P-value: 0.541685783467285
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.2 may not outperform SelectKBest.
# ____________________________________________________________________________________________
# T-statistic: -0.34694147915538226
# P-value: 0.7874024281025154
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.25 may not outperform SelectKBest.
# T-statistic: 0.8769233411639253
# P-value: 0.541685783467285
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.25 may not outperform SelectKBest.
# ____________________________________________________________________________________________
# T-statistic: 1.263795108257825
# P-value: 0.42614915107097195
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.3 may not outperform SelectKBest.
# T-statistic: 0.9045760247650608
# P-value: 0.5318695779598037
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.3 may not outperform SelectKBest.
# ____________________________________________________________________________________________
# T-statistic: 1.263795108257825
# P-value: 0.42614915107097195
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.4 may not outperform SelectKBest.
# T-statistic: 0.8932449442531328
# P-value: 0.535859325577751
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.4 may not outperform SelectKBest.
# ____________________________________________________________________________________________
# T-statistic: 1.263795108257825
# P-value: 0.42614915107097195
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.5 may not outperform SelectKBest.
# T-statistic: 0.8988981164004469
# P-value: 0.5338631876248265
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.5 may not outperform SelectKBest.
# ____________________________________________________________________________________________
# T-statistic: 1.0
# P-value: 0.49999999999999956
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.6 may not outperform SelectKBest.
# T-statistic: 0.6855250945360412
# P-value: 0.6174264929992169
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.6 may not outperform SelectKBest.
# ____________________________________________________________________________________________
# T-statistic: -0.44743511409823733
# P-value: 0.7321620176347763
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.7 may not outperform SelectKBest.
# T-statistic: -1.5995579697940983
# P-value: 0.35569443108099585
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.7 may not outperform SelectKBest.
# ____________________________________________________________________________________________
# T-statistic: -0.9976860978366023
# P-value: 0.5007373907298855
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.75 may not outperform SelectKBest.
# T-statistic: -1.0152481797781674
# P-value: 0.49518317019501873
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.75 may not outperform SelectKBest.
# ____________________________________________________________________________________________
# T-statistic: -0.9985949505761023
# P-value: 0.5004475554672989
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.8 may not outperform SelectKBest.
# T-statistic: -1.0111693631435674
# P-value: 0.4964644626908829
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.8 may not outperform SelectKBest.
# ____________________________________________________________________________________________
# T-statistic: nan
# P-value: nan
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.9 may not outperform SelectKBest.
# T-statistic: nan
# P-value: nan
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.9 may not outperform SelectKBest.
# ____________________________________________________________________________________________
# T-statistic: -1.0
# P-value: 0.49999999999999956
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.1 may not outperform VarianceThreshold.
# T-statistic: 0.7137726469203276
# P-value: 0.6053532471631158
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.1 may not outperform VarianceThreshold.
# ____________________________________________________________________________________________
# T-statistic: -1.0
# P-value: 0.49999999999999956
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.2 may not outperform VarianceThreshold.
# T-statistic: 0.7183943808801768
# P-value: 0.6034082868824024
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.2 may not outperform VarianceThreshold.
# ____________________________________________________________________________________________
# T-statistic: -1.0
# P-value: 0.49999999999999956
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.25 may not outperform VarianceThreshold.
# T-statistic: 0.7183943808801768
# P-value: 0.6034082868824024
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.25 may not outperform VarianceThreshold.
# ____________________________________________________________________________________________
# T-statistic: nan
# P-value: nan
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.3 may not outperform VarianceThreshold.
# T-statistic: 0.9510838069059557
# P-value: 0.5159575377006465
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.3 may not outperform VarianceThreshold.
# ____________________________________________________________________________________________
# T-statistic: nan
# P-value: nan
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.4 may not outperform VarianceThreshold.
# T-statistic: -1.0
# P-value: 0.49999999999999956
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.4 may not outperform VarianceThreshold.
# ____________________________________________________________________________________________
# T-statistic: nan
# P-value: nan
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.5 may not outperform VarianceThreshold.
# T-statistic: nan
# P-value: nan
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.5 may not outperform VarianceThreshold.
# ____________________________________________________________________________________________
# T-statistic: 0.6097555678371887
# P-value: 0.6514112998306232
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.6 may not outperform VarianceThreshold.
# T-statistic: -0.9613206659116185
# P-value: 0.5125531932501382
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.6 may not outperform VarianceThreshold.
# ____________________________________________________________________________________________
# T-statistic: -0.6256777565284177
# P-value: 0.6440744526613347
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.7 may not outperform VarianceThreshold.
# T-statistic: -1.0031471418211517
# P-value: 0.4989998083418386
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.7 may not outperform VarianceThreshold.
# ____________________________________________________________________________________________
# T-statistic: -0.9979970006494975
# P-value: 0.50063821345226
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.75 may not outperform VarianceThreshold.
# T-statistic: -1.119068271897322
# P-value: 0.46426656247376136
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.75 may not outperform VarianceThreshold.
# ____________________________________________________________________________________________
# T-statistic: -0.9987831788240786
# P-value: 0.5003875619589638
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.8 may not outperform VarianceThreshold.
# T-statistic: -1.085970760517391
# P-value: 0.4737773268522622
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.8 may not outperform VarianceThreshold.
# ____________________________________________________________________________________________
# T-statistic: nan
# P-value: nan
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.9 may not outperform VarianceThreshold.
# T-statistic: nan
# P-value: nan
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.9 may not outperform VarianceThreshold.
# ____________________________________________________________________________________________
# T-statistic: -1.0
# P-value: 0.49999999999999956
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.1 may not outperform VIF.
# T-statistic: -1.0
# P-value: 0.49999999999999956
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.1 may not outperform VIF.
# ____________________________________________________________________________________________
# T-statistic: -1.0
# P-value: 0.49999999999999956
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.2 may not outperform VIF.
# T-statistic: -1.0
# P-value: 0.49999999999999956
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.2 may not outperform VIF.
# ____________________________________________________________________________________________
# T-statistic: -1.0
# P-value: 0.49999999999999956
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.25 may not outperform VIF.
# T-statistic: -1.0
# P-value: 0.49999999999999956
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.25 may not outperform VIF.
# ____________________________________________________________________________________________
# T-statistic: 1.0
# P-value: 0.49999999999999956
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.3 may not outperform VIF.
# T-statistic: -1.0
# P-value: 0.49999999999999956
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.3 may not outperform VIF.
# ____________________________________________________________________________________________
# T-statistic: 1.0
# P-value: 0.49999999999999956
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.4 may not outperform VIF.
# T-statistic: -1.824081733685025
# P-value: 0.31924978339711796
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.4 may not outperform VIF.
# ____________________________________________________________________________________________
# T-statistic: 1.0
# P-value: 0.49999999999999956
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.5 may not outperform VIF.
# T-statistic: -1.727522817004431
# P-value: 0.33405540084638363
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.5 may not outperform VIF.
# ____________________________________________________________________________________________
# T-statistic: 0.861770970020168
# P-value: 0.5471799001698805
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.6 may not outperform VIF.
# T-statistic: -1.0390371211984368
# P-value: 0.48781347953918247
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.6 may not outperform VIF.
# ____________________________________________________________________________________________
# T-statistic: -0.48787247520325744
# P-value: 0.7110391740336981
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.7 may not outperform VIF.
# T-statistic: -1.053269517573426
# P-value: 0.48348739785046485
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.7 may not outperform VIF.
# ____________________________________________________________________________________________
# T-statistic: -0.9979941124346016
# P-value: 0.5006391346442416
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.75 may not outperform VIF.
# T-statistic: -1.1326159123846464
# P-value: 0.46046295054488745
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.75 may not outperform VIF.
# ____________________________________________________________________________________________
# T-statistic: -0.9987821135148751
# P-value: 0.5003879014704692
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.8 may not outperform VIF.
# T-statistic: -1.0956260447081017
# P-value: 0.4709703787792435
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.8 may not outperform VIF.
# ____________________________________________________________________________________________
# T-statistic: nan
# P-value: nan
# The difference in the mean F1 cannot be proved to be statistically significant; STEF-Rank_0.9 may not outperform VIF.
# T-statistic: nan
# P-value: nan
# The difference in the mean AUC-PR cannot be proved to be statistically significant; STEF-Rank_0.9 may not outperform VIF.
