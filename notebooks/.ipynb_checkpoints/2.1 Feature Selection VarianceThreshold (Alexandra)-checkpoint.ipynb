# %% [markdown]
# # 1. Imports

# %%
import pandas as pd
from sklearn import preprocessing
import numpy as np
from sklearn.feature_selection import VarianceThreshold

# %% [markdown]
# # 2. Importing the Datasets

# %%
ddos_portmap_2018_df = pd.read_csv("../data/train_test/CSE_CIC_IDS2018/ddos_portmap_2018_train.csv", index_col=0)

# %%
ddos_ldap_2019_df = pd.read_csv("../data/train_test/CIC_DDoS2019/ddos_ldap_2019_train.csv", index_col=0)

# %%
ddos_netbios_2019_df = pd.read_csv("../data/train_test/CIC_DDoS2019/ddos_netbios_2019_train.csv", index_col=0)

# %%
ddos_syn_2019_df = pd.read_csv("../data/train_test/CIC_DDoS2019/ddos_syn_2019_train.csv", index_col=0)

# %%
ddos_udp_2019_df = pd.read_csv("../data/train_test/CIC_DDoS2019/ddos_udp_2019_train.csv", index_col=0)

# %%
target_feature = 'Label'

# %% [markdown]
# # 3. Feature Selection - Variance Threshold
#
# ### Helper Functions

# %%
def VarianceThreshold_Helper(X_train, threshold):
    
    new_X_train = X_train.copy()

    constant_filter = VarianceThreshold(threshold= threshold)
    constant_filter.fit(new_X_train)

    len(new_X_train.columns[constant_filter.get_support()])

    constant_columns = [column for column in new_X_train.columns
                        if column not in new_X_train.columns[constant_filter.get_support()]]

    new_X_train.drop(labels=constant_columns, axis=1, inplace=True)
    
    return new_X_train.columns.tolist()

# %%
def stable_VarianceThreshold(train_df, num_splits, threshold, verbose):
    
    selectedFeatures = []
    
    df_split = np.array_split(train_df, num_splits)
    
    for small_df in df_split:
        X_train = small_df.drop([target_feature], axis=1)
        y_train = small_df[target_feature]
        
        selectedFeatures = selectedFeatures + VarianceThreshold_Helper(X_train, threshold)
        # NOTE TO ARYAN, PRANAV, AND ANISHA: THIS IS THE LINE YOU SHOULD CHANGE, AFTER IMPLEMENTING YOUR FEATURE
        # SELECTION METHOD
        
    rank_data = {}
    features = train_df.columns.tolist()
    ranks = []
        
    for feature in features:
        if verbose :
            print("Feature: "+feature+". Count: "+str(selectedFeatures.count(feature))+"/"+str(num_splits))
        ranks.append(selectedFeatures.count(feature)/num_splits)
    
    rank_data = {'feature':features, 'rank':ranks}
    rank_df = pd.DataFrame(rank_data) 
    
    return rank_df

# %% [markdown]
# ### Investigating a Good Choice of Threshold

# %%
X_train_portmap = ddos_portmap_2018_df.drop([target_feature], axis=1)
y_train_portmap = ddos_portmap_2018_df[target_feature]

# %%
X_train_portmap.columns
# Out:
# Index(['DestinationPort', 'FlowDuration', 'TotalFwdPackets',
#        'TotalBackwardPackets', 'TotalLengthofFwdPackets',
#        'TotalLengthofBwdPackets', 'FwdPacketLengthMax', 'FwdPacketLengthMin',
#        'FwdPacketLengthMean', 'FwdPacketLengthStd', 'BwdPacketLengthMax',
#        'BwdPacketLengthMin', 'BwdPacketLengthMean', 'BwdPacketLengthStd',
#        'FlowBytes/s', 'FlowPackets/s', 'FlowIATMean', 'FlowIATStd',
#        'FlowIATMax', 'FlowIATMin', 'FwdIATTotal', 'FwdIATMean', 'FwdIATStd',
#        'FwdIATMax', 'FwdIATMin', 'BwdIATTotal', 'BwdIATMean', 'BwdIATStd',
#        'BwdIATMax', 'BwdIATMin', 'FwdPSHFlags', 'BwdPSHFlags', 'FwdURGFlags',
#        'BwdURGFlags', 'FwdHeaderLength', 'BwdHeaderLength', 'FwdPackets/s',
#        'BwdPackets/s', 'MinPacketLength', 'MaxPacketLength',
#        'PacketLengthMean', 'PacketLengthStd', 'PacketLengthVariance',
#        'FINFlagCount', 'SYNFlagCount', 'RSTFlagCount', 'PSHFlagCount',
#        'ACKFlagCount', 'URGFlagCount', 'CWEFlagCount', 'ECEFlagCount',
#        'Down/UpRatio', 'AveragePacketSize', 'AvgFwdSegmentSize',
#        'AvgBwdSegmentSize', 'FwdHeaderLength.1', 'FwdAvgBytes/Bulk',
#        'FwdAvgPackets/Bulk', 'FwdAvgBulkRate', 'BwdAvgBytes/Bulk',
#        'BwdAvgPackets/Bulk', 'BwdAvgBulkRate', 'SubflowFwdPackets',
#        'SubflowFwdBytes', 'SubflowBwdPackets', 'SubflowBwdBytes',
#        'Init_Win_bytes_forward', 'Init_Win_bytes_backward', 'act_data_pkt_fwd',
#        'min_seg_size_forward', 'ActiveMean', 'ActiveStd', 'ActiveMax',
#        'ActiveMin', 'IdleMean', 'IdleStd', 'IdleMax', 'IdleMin'],
#       dtype='object')

# %%
for t in [0.00001, 0.0001, 0.001, 0.01, 0.02, 0.05, 0.1, 0.2, 0.3]:
    features = VarianceThreshold_Helper(X_train = X_train_portmap, threshold = t)
    print("Variance Threshold "+str(t)+": "+". Features: ("+str(len(features))+") "+str(features))
    print("_______________________________________________________________________________")
# Out:
# Variance Threshold 1e-05: . Features: (68) ['DestinationPort', 'FlowDuration', 'TotalFwdPackets', 'TotalBackwardPackets', 'TotalLengthofFwdPackets', 'TotalLengthofBwdPackets', 'FwdPacketLengthMax', 'FwdPacketLengthMin', 'FwdPacketLengthMean', 'FwdPacketLengthStd', 'BwdPacketLengthMax', 'BwdPacketLengthMin', 'BwdPacketLengthMean', 'BwdPacketLengthStd', 'FlowBytes/s', 'FlowPackets/s', 'FlowIATMean', 'FlowIATStd', 'FlowIATMax', 'FlowIATMin', 'FwdIATTotal', 'FwdIATMean', 'FwdIATStd', 'FwdIATMax', 'FwdIATMin', 'BwdIATTotal', 'BwdIATMean', 'BwdIATStd', 'BwdIATMax', 'BwdIATMin', 'FwdPSHFlags', 'FwdHeaderLength', 'BwdHeaderLength', 'FwdPackets/s', 'BwdPackets/s', 'MinPacketLength', 'MaxPacketLength', 'PacketLengthMean', 'PacketLengthStd', 'PacketLengthVariance', 'FINFlagCount', 'SYNFlagCount', 'RSTFlagCount', 'PSHFlagCount', 'ACKFlagCount', 'URGFlagCount', 'ECEFlagCount', 'Down/UpRatio', 'AveragePacketSize', 'AvgFwdSegmentSize', 'AvgBwdSegmentSize', 'FwdHeaderLength.1', 'SubflowFwdPackets', 'SubflowFwdBytes', 'SubflowBwdPackets', 'SubflowBwdBytes', 'Init_Win_bytes_forward', 'Init_Win_bytes_backward', 'act_data_pkt_fwd', 'min_seg_size_forward', 'ActiveMean', 'ActiveStd', 'ActiveMax', 'ActiveMin', 'IdleMean', 'IdleStd', 'IdleMax', 'IdleMin']
# _______________________________________________________________________________
# Variance Threshold 0.0001: . Features: (52) ['DestinationPort', 'FlowDuration', 'TotalLengthofFwdPackets', 'FwdPacketLengthMax', 'FwdPacketLengthMin', 'FwdPacketLengthMean', 'FwdPacketLengthStd', 'BwdPacketLengthMax', 'BwdPacketLengthMin', 'BwdPacketLengthMean', 'BwdPacketLengthStd', 'FlowPackets/s', 'FlowIATMean', 'FlowIATStd', 'FlowIATMax', 'FwdIATTotal', 'FwdIATMean', 'FwdIATStd', 'FwdIATMax', 'FwdIATMin', 'BwdIATTotal', 'BwdIATMean', 'BwdIATStd', 'BwdIATMax', 'BwdIATMin', 'FwdPSHFlags', 'FwdPackets/s', 'BwdPackets/s', 'MinPacketLength', 'MaxPacketLength', 'PacketLengthMean', 'PacketLengthStd', 'PacketLengthVariance', 'FINFlagCount', 'SYNFlagCount', 'RSTFlagCount', 'PSHFlagCount', 'ACKFlagCount', 'URGFlagCount', 'ECEFlagCount', 'Down/UpRatio', 'AveragePacketSize', 'AvgFwdSegmentSize', 'AvgBwdSegmentSize', 'SubflowFwdBytes', 'Init_Win_bytes_forward', 'Init_Win_bytes_backward', 'min_seg_size_forward', 'IdleMean', 'IdleStd', 'IdleMax', 'IdleMin']
# _______________________________________________________________________________
# Variance Threshold 0.001: . Features: (44) ['DestinationPort', 'FlowDuration', 'FwdPacketLengthMax', 'FwdPacketLengthMin', 'FwdPacketLengthMean', 'FwdPacketLengthStd', 'BwdPacketLengthMax', 'BwdPacketLengthMin', 'BwdPacketLengthMean', 'BwdPacketLengthStd', 'FlowIATStd', 'FlowIATMax', 'FwdIATTotal', 'FwdIATMean', 'FwdIATStd', 'FwdIATMax', 'BwdIATTotal', 'BwdIATMean', 'BwdIATStd', 'BwdIATMax', 'BwdIATMin', 'FwdPSHFlags', 'FwdPackets/s', 'MinPacketLength', 'MaxPacketLength', 'PacketLengthMean', 'PacketLengthStd', 'PacketLengthVariance', 'FINFlagCount', 'SYNFlagCount', 'PSHFlagCount', 'ACKFlagCount', 'URGFlagCount', 'Down/UpRatio', 'AveragePacketSize', 'AvgFwdSegmentSize', 'AvgBwdSegmentSize', 'Init_Win_bytes_forward', 'Init_Win_bytes_backward', 'min_seg_size_forward', 'IdleMean', 'IdleStd', 'IdleMax', 'IdleMin']
# _______________________________________________________________________________
# Variance Threshold 0.01: . Features: (34) ['DestinationPort', 'FlowDuration', 'FwdPacketLengthMax', 'FwdPacketLengthMin', 'FwdPacketLengthMean', 'FwdPacketLengthStd', 'BwdPacketLengthMax', 'BwdPacketLengthMean', 'BwdPacketLengthStd', 'FlowIATStd', 'FlowIATMax', 'FwdIATTotal', 'FwdIATStd', 'FwdIATMax', 'BwdIATTotal', 'BwdIATMax', 'FwdPSHFlags', 'MaxPacketLength', 'PacketLengthMean', 'PacketLengthStd', 'PacketLengthVariance', 'SYNFlagCount', 'PSHFlagCount', 'ACKFlagCount', 'URGFlagCount', 'Down/UpRatio', 'AveragePacketSize', 'AvgFwdSegmentSize', 'AvgBwdSegmentSize', 'Init_Win_bytes_forward', 'IdleMean', 'IdleStd', 'IdleMax', 'IdleMin']
# _______________________________________________________________________________
# Variance Threshold 0.02: . Features: (26) ['DestinationPort', 'FlowDuration', 'FwdPacketLengthMax', 'BwdPacketLengthMax', 'BwdPacketLengthMean', 'BwdPacketLengthStd', 'FlowIATMax', 'FwdIATTotal', 'FwdIATMax', 'BwdIATTotal', 'FwdPSHFlags', 'MaxPacketLength', 'PacketLengthMean', 'PacketLengthStd', 'PacketLengthVariance', 'SYNFlagCount', 'PSHFlagCount', 'ACKFlagCount', 'URGFlagCount', 'Down/UpRatio', 'AveragePacketSize', 'AvgBwdSegmentSize', 'IdleMean', 'IdleStd', 'IdleMax', 'IdleMin']
# _______________________________________________________________________________
# Variance Threshold 0.05: . Features: (13) ['DestinationPort', 'FlowDuration', 'BwdPacketLengthMax', 'FwdIATTotal', 'FwdIATMax', 'MaxPacketLength', 'PacketLengthMean', 'PacketLengthStd', 'PSHFlagCount', 'ACKFlagCount', 'URGFlagCount', 'AveragePacketSize', 'IdleMax']
# _______________________________________________________________________________
# Variance Threshold 0.1: . Features: (5) ['BwdPacketLengthMax', 'MaxPacketLength', 'PSHFlagCount', 'ACKFlagCount', 'URGFlagCount']
# _______________________________________________________________________________
# Variance Threshold 0.2: . Features: (2) ['PSHFlagCount', 'ACKFlagCount']
# _______________________________________________________________________________
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-5f6825f675a7> in <module>
#       1 for t in [0.00001, 0.0001, 0.001, 0.01, 0.02, 0.05, 0.1, 0.2, 0.3]:
# ----> 2     features = VarianceThreshold_Helper(X_train = X_train_portmap, threshold = t)
#       3     print("Variance Threshold "+str(t)+": "+". Features: ("+str(len(features))+") "+str(features))
#       4     print("_______________________________________________________________________________")
#
# <ipython-input-8-43919e9580cb> in VarianceThreshold_Helper(X_train, threshold)
#       4
#       5     constant_filter = VarianceThreshold(threshold= threshold)
# ----> 6     constant_filter.fit(new_X_train)
#       7
#       8     len(new_X_train.columns[constant_filter.get_support()])
#
# c:\users\alexa\appdata\local\programs\python\python38\lib\site-packages\sklearn\base.py in wrapper(estimator, *args, **kwargs)
#    1150                 )
#    1151             ):
# -> 1152                 return fit_method(estimator, *args, **kwargs)
#    1153
#    1154         return wrapper
#
# c:\users\alexa\appdata\local\programs\python\python38\lib\site-packages\sklearn\feature_selection\_variance_threshold.py in fit(self, X, y)
#     124             if X.shape[0] == 1:
#     125                 msg += " (X contains only one sample)"
# --> 126             raise ValueError(msg.format(self.threshold))
#     127
#     128         return self
#
# ValueError: No feature in X meets the variance threshold 0.30000

# %% [markdown]
# # 4. Saving the Rankings

# %%
portmap_ranking = stable_VarianceThreshold(ddos_portmap_2018_df, 10, 0.00005, verbose=False)
portmap_ranking.to_csv("../ranking/CSE_CIC_IDS2018/ddos_portmap_2018_VarianceThreshold.csv")
portmap_ranking.head(20)
# Out:
#                     feature  rank
# 0           DestinationPort   1.0
# 1              FlowDuration   1.0
# 2           TotalFwdPackets   0.3
# 3      TotalBackwardPackets   0.2
# 4   TotalLengthofFwdPackets   1.0
# 5   TotalLengthofBwdPackets   0.3
# 6        FwdPacketLengthMax   1.0
# 7        FwdPacketLengthMin   1.0
# 8       FwdPacketLengthMean   1.0
# 9        FwdPacketLengthStd   1.0
# 10       BwdPacketLengthMax   1.0
# 11       BwdPacketLengthMin   1.0
# 12      BwdPacketLengthMean   1.0
# 13       BwdPacketLengthStd   1.0
# 14              FlowBytes/s   0.6
# 15            FlowPackets/s   1.0
# 16              FlowIATMean   1.0
# 17               FlowIATStd   1.0
# 18               FlowIATMax   1.0
# 19               FlowIATMin   0.4

# %%
ldap_ranking = stable_VarianceThreshold(ddos_ldap_2019_df, 10, 0.00005, verbose=False)
ldap_ranking.to_csv("../ranking/CIC_DDoS2019/ddos_ldap_2019_VarianceThreshold.csv")
ldap_ranking.head(20)
# Out:
#                     feature  rank
# 0                    FlowID   1.0
# 1                  SourceIP   1.0
# 2                SourcePort   1.0
# 3             DestinationIP   1.0
# 4           DestinationPort   1.0
# 5                  Protocol   1.0
# 6              FlowDuration   1.0
# 7           TotalFwdPackets   0.5
# 8      TotalBackwardPackets   0.1
# 9   TotalLengthofFwdPackets   0.1
# 10  TotalLengthofBwdPackets   0.1
# 11       FwdPacketLengthMax   1.0
# 12       FwdPacketLengthMin   1.0
# 13      FwdPacketLengthMean   1.0
# 14       FwdPacketLengthStd   1.0
# 15       BwdPacketLengthMax   1.0
# 16       BwdPacketLengthMin   0.3
# 17      BwdPacketLengthMean   1.0
# 18       BwdPacketLengthStd   1.0
# 19              FlowBytes/s   1.0

# %%
netbios_ranking = stable_VarianceThreshold(ddos_netbios_2019_df, 10, 0.00005, verbose=False)
netbios_ranking.to_csv("../ranking/CIC_DDoS2019/ddos_netbios_2019_VarianceThreshold.csv")
netbios_ranking.head(20)
# Out:
#                     feature  rank
# 0                    FlowID   1.0
# 1                  SourceIP   1.0
# 2                SourcePort   1.0
# 3             DestinationIP   1.0
# 4           DestinationPort   1.0
# 5                  Protocol   1.0
# 6              FlowDuration   1.0
# 7           TotalFwdPackets   0.0
# 8      TotalBackwardPackets   0.1
# 9   TotalLengthofFwdPackets   0.3
# 10  TotalLengthofBwdPackets   0.2
# 11       FwdPacketLengthMax   1.0
# 12       FwdPacketLengthMin   1.0
# 13      FwdPacketLengthMean   1.0
# 14       FwdPacketLengthStd   0.8
# 15       BwdPacketLengthMax   1.0
# 16       BwdPacketLengthMin   1.0
# 17      BwdPacketLengthMean   0.8
# 18       BwdPacketLengthStd   1.0
# 19              FlowBytes/s   1.0

# %%
syn_ranking = stable_VarianceThreshold(ddos_syn_2019_df, 10, 0.00005, verbose=False)
syn_ranking.to_csv("../ranking/CIC_DDoS2019/ddos_syn_2019_VarianceThreshold.csv")
syn_ranking.head(20)
# Out:
#                     feature  rank
# 0                    FlowID   1.0
# 1                  SourceIP   1.0
# 2                SourcePort   1.0
# 3             DestinationIP   1.0
# 4           DestinationPort   1.0
# 5                  Protocol   1.0
# 6              FlowDuration   1.0
# 7           TotalFwdPackets   0.0
# 8      TotalBackwardPackets   0.1
# 9   TotalLengthofFwdPackets   0.3
# 10  TotalLengthofBwdPackets   0.1
# 11       FwdPacketLengthMax   0.7
# 12       FwdPacketLengthMin   0.3
# 13      FwdPacketLengthMean   0.4
# 14       FwdPacketLengthStd   0.4
# 15       BwdPacketLengthMax   0.8
# 16       BwdPacketLengthMin   1.0
# 17      BwdPacketLengthMean   0.4
# 18       BwdPacketLengthStd   0.8
# 19              FlowBytes/s   0.1

# %%
udp_ranking = stable_VarianceThreshold(ddos_udp_2019_df, 10, 0.00005, verbose=False)
udp_ranking.to_csv("../ranking/CIC_DDoS2019/ddos_udp_2019_VarianceThreshold.csv")
udp_ranking.head(20)
# Out:
#                     feature  rank
# 0                    FlowID   1.0
# 1                  SourceIP   1.0
# 2                SourcePort   1.0
# 3             DestinationIP   1.0
# 4           DestinationPort   1.0
# 5                  Protocol   1.0
# 6              FlowDuration   1.0
# 7           TotalFwdPackets   1.0
# 8      TotalBackwardPackets   1.0
# 9   TotalLengthofFwdPackets   1.0
# 10  TotalLengthofBwdPackets   0.6
# 11       FwdPacketLengthMax   1.0
# 12       FwdPacketLengthMin   1.0
# 13      FwdPacketLengthMean   1.0
# 14       FwdPacketLengthStd   1.0
# 15       BwdPacketLengthMax   1.0
# 16       BwdPacketLengthMin   1.0
# 17      BwdPacketLengthMean   1.0
# 18       BwdPacketLengthStd   1.0
# 19              FlowBytes/s   1.0

# %% [markdown]
# # 5. Baselines

# %%
def baseline_VarianceThreshold(train_df, threshold, verbose):
    
    selectedFeatures = []
    
    X_train = train_df.drop([target_feature], axis=1)
    y_train = train_df[target_feature]
        
    selectedFeatures =  VarianceThreshold_Helper(X_train, threshold)
        
    rank_data = {}
    features = train_df.columns.tolist()
    ranks = []
        
    for feature in features:
        if verbose :
            print("Feature: "+feature+". Count: "+str(selectedFeatures.count(feature)))
        ranks.append(selectedFeatures.count(feature))
    
    rank_data = {'feature':features, 'rank':ranks}
    rank_df = pd.DataFrame(rank_data)
    
    return rank_df

# %%
portmap_ranking_baseline = baseline_VarianceThreshold(ddos_portmap_2018_df, 0.005, verbose=False)
portmap_ranking_baseline.to_csv("../baseline_ranking/CSE_CIC_IDS2018/ddos_portmap_2018_VarianceThreshold.csv")
portmap_ranking_baseline.head(5)
# Out:
#                    feature  rank
# 0          DestinationPort     1
# 1             FlowDuration     1
# 2          TotalFwdPackets     0
# 3     TotalBackwardPackets     0
# 4  TotalLengthofFwdPackets     0

# %%
ldap_ranking_baseline = baseline_VarianceThreshold(ddos_ldap_2019_df, 0.005, verbose=False)
ldap_ranking_baseline.to_csv("../baseline_ranking/CIC_DDoS2019/ddos_ldap_2019_VarianceThreshold.csv")
ldap_ranking_baseline.head(5)
# Out:
#            feature  rank
# 0           FlowID     1
# 1         SourceIP     0
# 2       SourcePort     1
# 3    DestinationIP     0
# 4  DestinationPort     1

# %%
udp_ranking_baseline = baseline_VarianceThreshold(ddos_udp_2019_df, 0.005, verbose=False)
udp_ranking_baseline.to_csv("../baseline_ranking/CIC_DDoS2019/ddos_udp_2019_VarianceThreshold.csv")
udp_ranking_baseline.head(5)
# Out:
#            feature  rank
# 0           FlowID     1
# 1         SourceIP     1
# 2       SourcePort     1
# 3    DestinationIP     1
# 4  DestinationPort     1

# %%
netbios_ranking_baseline = baseline_VarianceThreshold(ddos_netbios_2019_df, 0.005, verbose=False)
netbios_ranking_baseline.to_csv("../baseline_ranking/CIC_DDoS2019/ddos_netbios_2019_VarianceThreshold.csv")
netbios_ranking_baseline.head(5)
# Out:
#            feature  rank
# 0           FlowID     1
# 1         SourceIP     0
# 2       SourcePort     1
# 3    DestinationIP     0
# 4  DestinationPort     1

# %%
syn_ranking_baseline = baseline_VarianceThreshold(ddos_syn_2019_df, 0.005, verbose=False)
syn_ranking_baseline.to_csv("../baseline_ranking/CIC_DDoS2019/ddos_syn_2019_VarianceThreshold.csv")
syn_ranking_baseline.head(5)
# Out:
#            feature  rank
# 0           FlowID     1
# 1         SourceIP     0
# 2       SourcePort     1
# 3    DestinationIP     0
# 4  DestinationPort     1

# %% [markdown]
# # 6. Repeat for Assignment Datasets

# %%
a2_train = pd.read_csv("../data/csi5388_assignment2_3_data/assignment2_train.csv", index_col=0)
a3_train = pd.read_csv("../data/csi5388_assignment2_3_data/assignment3_train.csv", index_col=0)

# %%
a2ranking = stable_VarianceThreshold(a2_train, 10, 0.0005, verbose=False)
a2ranking.to_csv("../ranking/csi5388_assignment2_3_data/assignment2_VarianceThreshold.csv")
a2ranking.head(60)
# Out:
#                         feature  rank
# 0                      duration   1.0
# 1                 protocol_type   1.0
# 2                       service   1.0
# 3                          flag   1.0
# 4                     src_bytes   1.0
# 5                     dst_bytes   1.0
# 6                          land   0.0
# 7                wrong_fragment   1.0
# 8                        urgent   0.0
# 9                           hot   1.0
# 10            num_failed_logins   0.7
# 11                    logged_in   1.0
# 12              num_compromised   1.0
# 13                   root_shell   0.8
# 14                 su_attempted   0.7
# 15                     num_root   1.0
# 16           num_file_creations   1.0
# 17                   num_shells   0.3
# 18             num_access_files   1.0
# 19            num_outbound_cmds   0.0
# 20                is_host_login   0.0
# 21               is_guest_login   1.0
# 22                        count   1.0
# 23                    srv_count   1.0
# 24                  serror_rate   1.0
# 25              srv_serror_rate   1.0
# 26                  rerror_rate   1.0
# 27              srv_rerror_rate   1.0
# 28                same_srv_rate   1.0
# 29                diff_srv_rate   1.0
# 30           srv_diff_host_rate   1.0
# 31               dst_host_count   1.0
# 32           dst_host_srv_count   1.0
# 33       dst_host_same_srv_rate   1.0
# 34       dst_host_diff_srv_rate   1.0
# 35  dst_host_same_src_port_rate   1.0
# 36  dst_host_srv_diff_host_rate   1.0
# 37         dst_host_serror_rate   1.0
# 38     dst_host_srv_serror_rate   1.0
# 39         dst_host_rerror_rate   1.0
# 40     dst_host_srv_rerror_rate   1.0
# 41                        level   1.0
# 42                        Label   0.0

# %%
a3ranking = stable_VarianceThreshold(a3_train, 10, 0.1, verbose=False)
a3ranking.to_csv("../ranking/csi5388_assignment2_3_data/assignment3_VarianceThreshold.csv")
a3ranking.head(20)
# Out:
#                 feature  rank
# 0   length_longest_word   1.0
# 1            FQDN_count   1.0
# 2               sld_vec   0.0
# 3           private_192   1.0
# 4                 lower   1.0
# 5             multicast   1.0
# 6               entropy   1.0
# 7            labels_max   1.0
# 8       admin_multicast   0.0
# 9           private_172   0.0
# 10                Label   0.0

# %%
# Baselines 

a2_baseline = baseline_VarianceThreshold(a2_train, 0.005, verbose=False)
a2_baseline.to_csv("../baseline_ranking/csi5388_assignment2_3_data/assignment2_VarianceThreshold.csv")
a2_baseline.head(5)
# Out:
#          feature  rank
# 0       duration     1
# 1  protocol_type     1
# 2        service     1
# 3           flag     1
# 4      src_bytes     1

# %%
a3_baseline = baseline_VarianceThreshold(a3_train, 0.1, verbose=False)
a3_baseline.to_csv("../baseline_ranking/csi5388_assignment2_3_data/assignment3_VarianceThreshold.csv")
a3_baseline.head(5)
# Out:
#                feature  rank
# 0  length_longest_word     1
# 1           FQDN_count     1
# 2              sld_vec     0
# 3          private_192     1
# 4                lower     1
